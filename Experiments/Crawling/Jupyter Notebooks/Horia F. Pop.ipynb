# %% [markdown]
# ## Manual publication DB insertion from raw text using syntax features
# ### Publications and conferences of Dr. POP F. Horia, Profesor Universitar
# #### http://www.cs.ubbcluj.ro/~hfpop

# %% [markdown]
# #### Text copied from professor's dynamic webpage.

# %%
text = """
Principal component analysis versus fuzzy principal component analysis: a case study: the quality of Danube water (1985–1996)
C Sarbu, HF Pop
Talanta 65 (5), 1215-1220	185	2005
Robust Fuzzy Principal Component Analysis (FPCA). A Comparative Study Concerning Interaction of Carbon− Hydrogen Bonds with Molybdenum− Oxo Bonds
TR Cundari, C Sârbu, HF Pop
Journal of chemical information and computer sciences 42 (6), 1363-1369	61	2002
A new fuzzy regression algorithm
HF Pop, C Sârbu
Analytical chemistry 68 (5), 771-778	57	1996
Introducere în algoritmi
TH Cormen, CE Leiserson, RR Rivest, HF Pop, S Motogna, PA Blaga
Computer Libris Agora	38	2004
A fuzzy classification of the chemical elements
HF Pop, C Sârbu, O Horowitz, D Dumitrescu
Journal of chemical information and computer sciences 36 (3), 465-482	32	1996
Fuzzy soft-computing methods and their applications in chemistry
C Sârbu, HF Pop
Reviews in Computational Chemistry 20, 249	26	2004
A fuzzy divisive hierarchical clustering algorithm for the optimal choice of sets of solvent systems
D Dumitrescu, C S [acaron] rbu, H Pop
Analytical letters 27 (5), 1031-1054	26	1994
Classical and fuzzy principal component analysis of some environmental samples concerning the pollution with heavy metals
HF Pop, JW Einax, C Sârbu
Chemometrics and Intelligent Laboratory Systems 97 (1), 25-32	25	2009
Structural Analysis of Transition Metal β-X Substituent Interactions. Toward the Use of Soft Computing Methods for Catalyst Modeling
TR Cundari, J Deng, HF Pop, C Sârbu
Journal of chemical information and computer sciences 40 (4), 1052-1061	24	2000
A study of Roman pottery (terra sigillata) using hierarchical fuzzy clustering
HF Pop, D Dumitrescu, C Sǎrbu
Analytica chimica acta 310 (2), 269-279	22	1995
Principal components analysis based on a fuzzy sets approach
H Pop
Mij 1 (2), 1	21	2001
Learning grammar weights using genetic algorithms
I Schröder, HF Pop, W Menzel, KA Foth
IN PROCEEDINGS RECENT ADVANCES IN NATURAL LANGUAGE PROCESSING, RANLP-2001	20	2001
Fuzzy clustering analysis of the first 10 MEIC chemicals
C Sârbu, HF Pop
Chemosphere 40 (5), 513-520	20	2000
A new component selection algorithm based on metrics and fuzzy clustering analysis
C Şerban, A Vescan, HF Pop
International Conference on Hybrid Artificial Intelligence Systems, 621-628	16	2009
The fuzzy hierarchical cross-clustering algorithm. Improvements and comparative study
HF Pop, C Sârbu
Journal of chemical information and computer sciences 37 (3), 510-516	16	1997
Fuzzy robust estimation of central location
C Sârbu, HF Pop
Talanta 54 (1), 125-130	15	2001
A Fuzzy cross-classification of the chemical elements, based on their physical, chemical, and structural features
C Sârbu, O Horowitz, HF Pop
Journal of chemical information and computer sciences 36 (6), 1098-1108	15	1996
Fuzzy hierarchical cross-classification of Greek muds
D Dumitrescu, HF Pop, C Sarbu
Journal of chemical information and computer sciences 35 (5), 851-857	15	1995
GFBA: a biclustering algorithm for discovering value-coherent biclusters
X Fei, S Lu, HF Pop, LR Liang
International Symposium on Bioinformatics Research and Applications, 1-12	14	2007
Degenerate and non-degenerate convex decomposition of finite fuzzy partitions—I
D Dumitrescu, HF Pop
Fuzzy sets and systems 73 (3), 365-376	14	1995
Data analysis with fuzzy sets: a short survey
HF Pop
Studia Universitatis Babes-Bolyai, Series Informatica 49 (2), 111-122	12	2004
A study of dependence of software attributes using data analysis techniques
M Frentiu, HF Pop
Studia Univ. Babes-Bolyai, Series Informatica 2, 53-66	12	2002
Selecting and optimally combining the systems of solvents in the thin film cromatography using the fuzzy sets theory
C Sârbu, D Dumitrescu, HF Pop
Rev. Chim.(Bucharest) 44, 450-459	12	1993
Software quality assessment using a fuzzy clustering approach
C Serban, HF POP
Studia Universitas Babes-Bolyai, Seria Informatica 53 (2), 27-38	9	2008
Evolutionary algorithms for the component selection problem
A Vescan, C Grosan, HF Pop
2008 19th International workshop on database and expert systems applications …	8	2008
Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti
G Serban, HF Pop
Ed. Mediamira, Cluj-Napoca	8	2004
Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti
G Serban, HF Pop
Ed. Mediamira, Cluj-Napoca	8	2004
An experiment on incremental analysis using robust parsing techniques
KA Foth, W Menzel, HF Pop, I Schroder
COLING 2000 Volume 2: The 18th International Conference on Computational …	8	2000
Intelligent Systems in Classification Problems
HF Pop
Ph. D. thesis," Babeş-Bolyai" University, Faculty of Mathematics and …	8	1995
A conceptual framework for component-based system metrics definition
C Şerban, A Vescan, HF Pop
9th RoEduNet IEEE International Conference, 73-78	7	2010
Intelligent disease identification based on discriminant analysis of clinical data
C Sarbu, HF Pop, R Elekes, G Covaci
Rev Chimie 59, 1237-1241	7	2008
The component selection problem as a constraint optimization problem
A Vescan, HF Pop
Software Engineering Techniques in Progress, Wroclaw University of …	7	2008
Learning weights for a natural language grammar using genetic algorithms
I Schröder, HF Pop, W Menzel, KA Foth
7	2002
Assessment of heart disease using fuzzy classification techniques
HF Pop, TL Pop, C Sârbu
TheScientificWorldJournal 1, 369-390	7	2001
A new fuzzy discriminant analysis method
HF Pop, C Sârbu
natural science (chemometrics, environmental sciences, biology, geology, etc …	6	2013
An experiment in incremental parsing using weighted constraints
K Foth, W Menzel, HF Pop, I Schröder
Proceedings of the 18th International Conference on Computational …	6	2000
Degenerate and non-degenerate convex decomposition of finite fuzzy partitions (II)
D Dumitrescu, HF Pop
Fuzzy sets and systems 96 (1), 111-118	6	1998
A formal model for component-based system assessment
C Serban, A Vescan, HF Pop
2010 Second International Conference on Computational Intelligence …	5	2010
An adaptive fuzzy agent clustering algorithm for search engines
RD Gaceanu, HF Pop
MACS2010: Proceedings of the 8th Joint Conference on Mathematics and …	5	2010
A study of licence examination results using Fuzzy Clustering techniques
M Frentiu, HF Pop
Babes-Bolyai University, Faculty of Mathematics and Computer Science …	5	2001
Fuzzy classification of the first 10 MEIC
C Sârbu, H Pop
Chemosphere 40 (513), e520	5	2000
Fuzzy regression. II. Outliers cases
HF Pop, C Sârbu
Revista de Chimie 48 (10-11), 888-891	5	1997
SAADI: Software for fuzzy clustering and related fields
HF Pop
Studia Universitatis Babes-Bolyai, Series Informatica 41 (1), 69-80	5	1996
Recognizing Emotions in Short Texts.
O Serban, A Pauchet, HF Pop
ICAART (1), 477-480	4	2012
An incremental ASM-based fuzzy clustering algorithm
RD Gaceanu, HF Pop
Informatics, 198-204	4	2011
A context-aware ASM-based clustering algorithm
RD GACEANU, HF Pop
Studia Universitatis Babes-Bolyai Series Informatica 56 (2), 55-61	4	2011
Automatic configuration for the component selection problem
A Vescan, HF Pop
Proceedings of the 5th international conference on Soft computing as …	4	2008
Component selection based on fuzzy clustering analysis
C Serban, A Vescan, HF Pop
Creative Mathematics and Informatics 17 (3), 505-510	4	2008
On Individual Projects in Software Engineering Education
M Frentiu, I Lazar, HF Pop
Studia Universitatis Babes-Bolyai Series Informatica 48 (2), 83-94	4	2003
Development of robust fuzzy regression techniques using a fuzzy clustering approach
HF Pop
Pure Mathematics and Applications 14 (3), 221-232	4	2003
Fuzzy classification and comparison of some Romanian and American coals
C Sârbu, HF Pop
MATCH-Communications in Mathematical and in Computer Chemistry, 387-400	4	2001
Fuzzy regression. 1. The heteroscedastic case
C Sârbu, H Pop
REVISTA DE CHIMIE 48 (8), 732-737	4	1997
DISCOVERING PATTERNS IN DATA USING ORDINAL DATA ANALYSIS.
AM COROIU, RD GĂCEANU, HF POP
Studia Universitatis Babes-Bolyai, Informatica 61 (1)	3	2016
Prognostic Factors in Liver Failure in Children by Discriminant Analysis of Clinical Data. A Chemometric Approach
HF Pop, C Sarbu, A Stefanescu, A Bizo, TL Pop
STUDIA UNIVERSITATIS BABES-BOLYAI CHEMIA 60 (2), 101-108	3	2015
Constraint optimization-based component selection problem
A Vescan, HF Pop
Studia Univ, Babes-Bolyai, Informatica 53 (2)	3	2008
Education for engineering students-The case of logic
H Pop, L Pop
Proceedings 6th International Conference on Electromechanical and Power …	3	2007
Tracking mistakes in software measurement using fuzzy data analysis
HF Pop, M Frenţiu
The 4-th International Conference RoEduNet Romania (Sovata, Târgu-Mures, 150-157	3	2005
Sisteme inteligente în probleme de clasificare
HF Pop
Mediamira	3	2004
Programare în inteligenţa artificială: LISP si PROLOG
HF Pop, G Şerban
Editura Albastră	3	2003
Rational Classification of the Chemical Elements
O Horovitz, C Sârbu, HF Pop
Dacia Publisher House, Cluj-Napoca	3	2000
Classification procedure for selectivity control in acrylonitrile electroreduction
DA Lowy, D Dumitrescu, L Oniciu, HF Pop, S Kiss-Szetsi
The 7th International Forum Process Analytical Chemistry (Process Analysis …	3	1993
Improving movement analysis in physical therapy systems based on kinect interaction
AD Călin, H F. Pop, R F. Boian
Proceedings of the 31st International BCS Human Computer Interaction …	2	2017
A fuzzy incremental clustering approach to hybrid data discovery
RD Gaceanu, HF Pop
Acta electrotechnica et informatica 12 (2), 16	2	2012
An incremental approach to the set covering problem
RD Gaceanu, HF Pop
Studia Universitatis Babes-Bolyai Series Informatica 47 (2), 61-72	2	2012
AP041 Joining the EuReCA–The Romanian Registry on Cardiac arrest–a year later
H Sabau, O Tudorache, H Pop, V Georgescu, V Strambu, I Dimitriu, ...
Resuscitation 82, S19	2	2011
A fuzzy clustering algorithm for dynamic environments
RD Gaceanu, HF POP
KEPT2011: Knowledge Engineering Principles and Techniques, Selected Papers …	2	2011
Romanian registry on cardiac arrest—A piece in the puzzle-Romanian contribution in the EuReCA project
V Georgescu, H Pop, O Tudorache, H Sabau, C Ciontu, I Dimitriu, ...
Resuscitation 81 (2), S39	2	2010
Effort Estimation by Analogy based on Soft Computing Methods, KEPT2009: Knowledge Engineering: Principles and Techniques, Selected Papers
HF Pop, M Frenţiu
Cluj University Press, Cluj-Napoca	2	2009
A New Component Selection Algorithm Based on Metrics and Fuzzy Clustering
C Serban, A Vescan, HF Pop
Creative Mathematics and Informatics 1 (3), 505-510	2	2009
Fundamentals of Programming
M Frenţiu, HF Pop
Cluj University Press	2	2006
Improving Virtual Team Performance: An Empirical Approach
D Radoiu, C Enachescu, HF Pop
A research paper of Sysgenic Sourcing, Available at sourcing. sysgenic. com …	2	2006
Supervised fuzzy classifiers
HF Pop
Studia Universitatis Babes-Bolyai, Series Mathematica 40 (3), 89-100	2	1995
OPTIMUM SELECTIONS AND COMBINATION OF SOLVENT SYSTEMS IN THIN-LAYER CHROMATOGRAPHY, USING THE FUZZY SET-THEORY
C Sârbu, D Dumitrescu, H Pop
Revista de Chimie 44 (5), 450-459	2	1993
Preliminary measurements in identifying design flaws
C SERBAN, A VESCAN, HF POP
Studia Universitatis Babes-Bolyai, Series Informatica 62 (1), 60-74	1	2017
AN AGENT BASED APPROACH FOR PARALLEL CONSTRAINT VERIFICATION
RD Gaceanu, HF Pop, SA Sotoc
Studia Universitatis Babes-Bolyai, Series Informatica 58 (3), 5-16	1	2013
An agent based approach for parallel constraint verification
RD Gaceanu, HF Pop, SA SOTOC
Studia Universitatis Babes-Bolyai Series Informatica 58 (3), 5-16	1	2013
Stereomatching using radiometric invariant measures
A Miron, S Ainouz, A Rogozan, A Bensrhair, HF POP
UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 91	1	2011
Improving similarity join algorithms using fuzzy clustering technique
L Tan, F Fotouhi, W Grosky, HF Pop, N Mouaddib
2009 IEEE International Conference on Data Mining Workshops, 545-550	1	2009
OVERVIEW OF FUZZY METHODS FOR EFFORT ESTIMATION BY ANALOGY.
M Frenţiu, HF Pop
Studia Universitatis Babes-Bolyai, Informatica	1	2009
Lighting quality-component of indoor environment
F Pop, HF Pop, M Pop
LUX Eur, 499-506	1	2009
Applications of principal components methods
HF Pop, M Frentiu
2008 First International Conference on Complexity and Intelligence of the …	1	2008
Programming Fundamentals
M Frenţiu, HF Pop, G Şerban
Presa Universitară Clujeană	1	2006
Distance Learning and Supporting Tools at Babeş-Bolyai University
FM Boian, RF Boian, A Vancea, HF Pop
1	
CHARACTERIZATION AND CLASSIFICATION OF MEDICINAL PLANT EXTRACTS ACCORDING TO THEIR ANTIOXIDANT ACTIVITY USING HIGH-PERFORMANCE LIQUID CHROMATOGRAPHY AND MULTIVARIATE ANALYSIS.
IM Simion, AC MOȚ, RD GĂCEANU, HF Pop, C Sarbu
Studia Universitatis Babes-Bolyai, Chemia 65 (1)		2020
A Comparison Study of Similarity Measures in Rough Sets Clustering
A Szederjesi-Dragomir, RD Găceanu, HF Pop, C Sârbu
2019 IEEE 15th International Scientific Conference on Informatics, 000037-000042		2019
A Machine Learning Perspective for Order Reduction in Electrical Motors Modeling
M Nutu, HF Pop, C Martis, SI Cosman, AM Nicorici
2019 21st International Symposium on Symbolic and Numeric Algorithms for …		2019
Principal Component Analysis for Computation of the Magnetization Characteristics of Synchronous Reluctance Machine
M Nutu, R Martis, HF Pop, C Martis
2018 AEIT International Annual Conference, 1-6		2018
SPECTROPHOTOMETRIC CHARACTERIZATION OF ROUMANIAN MEDICINAL HERBS ASSISTED BY ROBUST CHEMOMETRICS EXPERTISE
IM Simion, HF POPb, C Sarbu
Rev. Roum. Chim 63 (5-6), 489-496		2018
The Best Writing on Mathematics 2015
HF Pop
STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 61 (1), 123-124		2016
PROGNOSTIC FACTORS IN LIVER FAILURE IN CHILDREN BY DISCRIMINANT ANALYSIS OF CLINICAL DATA. A CHEMOMETRIC APPROACH.
C SÂRBU, A BIZO, TL POP, HF POP, ANA ŞTEFANESCU
Studia Universitatis Babes-Bolyai, Chemia 60		2015
The Best Writing on Mathematics 2014
HF Pop
STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 59 (3), 393-394		2014
Medical procedure breaches detection using a fuzzy clustering approach
R Găceanu, H Pop
Open Computer Science 4 (3), 127-140		2014
An incremental clustering approach to the set covering problem
RD Gaceanu, HF Pop
Zoltán Csörnyei (Ed.), 45		2012
Automatic criteria-based configuration for the component selection problem
A Vescan, HF Pop
International Journal of Computer Information Systems and Industrial …		2012
Recent developments in fuzzy statistical analysis
HF Pop
MaCS’10, 47		2010
PROCESSING ECG DATA USING MULTIVARIATE DATA ANALYSIS
MV PUŞCĂ, HF POP, NM ROMAN, V IANCU
ACADEMY OF ROMANIAN SCIENTISTS, 23		2010
M. Effort estimation by analogy based on soft computing methods
HF POP, M FRENTIU
KEPT 2009 International Conference Knowledge Engineering Principles and …		2009
Knowledge Engineering: Principles and Techniques: KEPT 2009: Cluj-Napoca, July 2-4, 2009
M Frențiu, HF Pop
Cluj University Press		2009
Iluminat eficient energetic în locuinţe
F Pop, D Beu, HF Pop, C Ciugudeanu
Revista Română de Informatică şi Automatică 18 (3), 101-112		2008
A Tutorial on Object-Oriented Functional Programming
HF Pop
Central European Functional Programming School, 228-249		2007
ON SOFTWARE ATTRIBUTES RELATIONSHIP USING A NEW FUZZY C-BIPARTITIONING METHOD
HF Pop, M Frentiu
Studia Universitatis Babes-Bolyai, Informatica Special Issue, 219-226		2007
Management of web pages using XML documents
L T ÂMBULEA, HF POP
Studia Universitatis Babes-Bolyai, Informatica Special Issue, 236-243		2007
Desired employment/Occupational field
N Italian, G Male
Cell 39, 081678652		2003
Appraisal of indoor lighting systems quality
M POP, HF POP, F POP
Ingineria Iluminatului, 37		2001
Papers from the 1999 Symposium on Mathematical Chemistry, Duluth, MN, May 1999-MOLECULAR MODELING-Structural Analysis of Transition Metal bX Substituent Interactions. Toward …
TR Cundari, J Deng, HF Pop, C Sarbu
Journal of Chemical Information and Computer Sciences 40 (4), 1052-1061		2000
Recognition of the forms applied to chemical elements
O Horowitz, C Sarbu, HF Pop
REVISTA DE CHIMIE 51 (1), 17-29		2000
REGRESIE FUZZY. II. CAZUL PUNCTELOR EXTREME (OUTLIERS)
HF POP, C SARBU
Revista de chimie 48 (10-11), 888-891		1997
REGRESIE FUZZY. I. CAZUL HETEROSCEDASTIC
C SARBU, H POP
Revista de chimie 48 (8), 732-737		1997
Desired employment Occupational field
F Horia
Education and training 1995		1992
KEPT2013: THE FOURTH INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING, PRINCIPLES AND TECHNIQUES
M FRENTIU, HF POP, S MOTOGNA
UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 5		
Object-oriented logic programming
HF Pop, MM Dogaru
LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat
F Horia, POP Florin
SAADI: Software for Fuzzy Clustering and Related Fields
F Horia
Residential Energy Efficient Lighting
POP Florin, F Horia
A guide for writing a scientific paper
M Frenţiu, HF Pop
Metode de recunoastere a formelor bazate pe agenti
UBB Îndrumator, HF Pop
THE FIRST INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING PRINCIPLES AND TECHNIQUES (KEPT 2007)
D TATAR, HF Pop, M FRENTIU, D Dumitrescu
COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER
M FRENTIU, HF POP
"""

# %%
mylines = []
    
ctr = 0

title = ""
authors = ""
affiliations = ""
date = ""

for line in text.split('\n')[1:]:
#     print(ctr, line)
    
    
    if ctr == 0:
        title = line
    elif ctr == 1:
        authors = line
    elif ctr == 2:
        affiliations = line.split('\t')[0]
        date = line.split('\t')[-1]
    
    ctr += 1
    if ctr == 3:
        mylines.append((title, authors, affiliations, date))
        print(mylines[-1])
        
        ctr = 0
        title = ""
        authors = ""
        affiliations = ""
        date = ""
# Out:
# ('Principal component analysis versus fuzzy principal component analysis: a case study: the quality of Danube water (1985–1996)', 'C Sarbu, HF Pop', 'Talanta 65 (5), 1215-1220', '2005')
# ('Robust Fuzzy Principal Component Analysis (FPCA). A Comparative Study Concerning Interaction of Carbon− Hydrogen Bonds with Molybdenum− Oxo Bonds', 'TR Cundari, C Sârbu, HF Pop', 'Journal of chemical information and computer sciences 42 (6), 1363-1369', '2002')
# ('A new fuzzy regression algorithm', 'HF Pop, C Sârbu', 'Analytical chemistry 68 (5), 771-778', '1996')
# ('Introducere în algoritmi', 'TH Cormen, CE Leiserson, RR Rivest, HF Pop, S Motogna, PA Blaga', 'Computer Libris Agora', '2004')
# ('A fuzzy classification of the chemical elements', 'HF Pop, C Sârbu, O Horowitz, D Dumitrescu', 'Journal of chemical information and computer sciences 36 (3), 465-482', '1996')
# ('Fuzzy soft-computing methods and their applications in chemistry', 'C Sârbu, HF Pop', 'Reviews in Computational Chemistry 20, 249', '2004')
# ('A fuzzy divisive hierarchical clustering algorithm for the optimal choice of sets of solvent systems', 'D Dumitrescu, C S [acaron] rbu, H Pop', 'Analytical letters 27 (5), 1031-1054', '1994')
# ('Classical and fuzzy principal component analysis of some environmental samples concerning the pollution with heavy metals', 'HF Pop, JW Einax, C Sârbu', 'Chemometrics and Intelligent Laboratory Systems 97 (1), 25-32', '2009')
# ('Structural Analysis of Transition Metal β-X Substituent Interactions. Toward the Use of Soft Computing Methods for Catalyst Modeling', 'TR Cundari, J Deng, HF Pop, C Sârbu', 'Journal of chemical information and computer sciences 40 (4), 1052-1061', '2000')
# ('A study of Roman pottery (terra sigillata) using hierarchical fuzzy clustering', 'HF Pop, D Dumitrescu, C Sǎrbu', 'Analytica chimica acta 310 (2), 269-279', '1995')
# ('Principal components analysis based on a fuzzy sets approach', 'H Pop', 'Mij 1 (2), 1', '2001')
# ('Learning grammar weights using genetic algorithms', 'I Schröder, HF Pop, W Menzel, KA Foth', 'IN PROCEEDINGS RECENT ADVANCES IN NATURAL LANGUAGE PROCESSING, RANLP-2001', '2001')
# ('Fuzzy clustering analysis of the first 10 MEIC chemicals', 'C Sârbu, HF Pop', 'Chemosphere 40 (5), 513-520', '2000')
# ('A new component selection algorithm based on metrics and fuzzy clustering analysis', 'C Şerban, A Vescan, HF Pop', 'International Conference on Hybrid Artificial Intelligence Systems, 621-628', '2009')
# ('The fuzzy hierarchical cross-clustering algorithm. Improvements and comparative study', 'HF Pop, C Sârbu', 'Journal of chemical information and computer sciences 37 (3), 510-516', '1997')
# ('Fuzzy robust estimation of central location', 'C Sârbu, HF Pop', 'Talanta 54 (1), 125-130', '2001')
# ('A Fuzzy cross-classification of the chemical elements, based on their physical, chemical, and structural features', 'C Sârbu, O Horowitz, HF Pop', 'Journal of chemical information and computer sciences 36 (6), 1098-1108', '1996')
# ('Fuzzy hierarchical cross-classification of Greek muds', 'D Dumitrescu, HF Pop, C Sarbu', 'Journal of chemical information and computer sciences 35 (5), 851-857', '1995')
# ('GFBA: a biclustering algorithm for discovering value-coherent biclusters', 'X Fei, S Lu, HF Pop, LR Liang', 'International Symposium on Bioinformatics Research and Applications, 1-12', '2007')
# ('Degenerate and non-degenerate convex decomposition of finite fuzzy partitions—I', 'D Dumitrescu, HF Pop', 'Fuzzy sets and systems 73 (3), 365-376', '1995')
# ('Data analysis with fuzzy sets: a short survey', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Informatica 49 (2), 111-122', '2004')
# ('A study of dependence of software attributes using data analysis techniques', 'M Frentiu, HF Pop', 'Studia Univ. Babes-Bolyai, Series Informatica 2, 53-66', '2002')
# ('Selecting and optimally combining the systems of solvents in the thin film cromatography using the fuzzy sets theory', 'C Sârbu, D Dumitrescu, HF Pop', 'Rev. Chim.(Bucharest) 44, 450-459', '1993')
# ('Software quality assessment using a fuzzy clustering approach', 'C Serban, HF POP', 'Studia Universitas Babes-Bolyai, Seria Informatica 53 (2), 27-38', '2008')
# ('Evolutionary algorithms for the component selection problem', 'A Vescan, C Grosan, HF Pop', '2008 19th International workshop on database and expert systems applications …', '2008')
# ('Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', 'G Serban, HF Pop', 'Ed. Mediamira, Cluj-Napoca', '2004')
# ('Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', 'G Serban, HF Pop', 'Ed. Mediamira, Cluj-Napoca', '2004')
# ('An experiment on incremental analysis using robust parsing techniques', 'KA Foth, W Menzel, HF Pop, I Schroder', 'COLING 2000 Volume 2: The 18th International Conference on Computational …', '2000')
# ('Intelligent Systems in Classification Problems', 'HF Pop', 'Ph. D. thesis," Babeş-Bolyai" University, Faculty of Mathematics and …', '1995')
# ('A conceptual framework for component-based system metrics definition', 'C Şerban, A Vescan, HF Pop', '9th RoEduNet IEEE International Conference, 73-78', '2010')
# ('Intelligent disease identification based on discriminant analysis of clinical data', 'C Sarbu, HF Pop, R Elekes, G Covaci', 'Rev Chimie 59, 1237-1241', '2008')
# ('The component selection problem as a constraint optimization problem', 'A Vescan, HF Pop', 'Software Engineering Techniques in Progress, Wroclaw University of …', '2008')
# ('Learning weights for a natural language grammar using genetic algorithms', 'I Schröder, HF Pop, W Menzel, KA Foth', '7', '2002')
# ('Assessment of heart disease using fuzzy classification techniques', 'HF Pop, TL Pop, C Sârbu', 'TheScientificWorldJournal 1, 369-390', '2001')
# ('A new fuzzy discriminant analysis method', 'HF Pop, C Sârbu', 'natural science (chemometrics, environmental sciences, biology, geology, etc …', '2013')
# ('An experiment in incremental parsing using weighted constraints', 'K Foth, W Menzel, HF Pop, I Schröder', 'Proceedings of the 18th International Conference on Computational …', '2000')
# ('Degenerate and non-degenerate convex decomposition of finite fuzzy partitions (II)', 'D Dumitrescu, HF Pop', 'Fuzzy sets and systems 96 (1), 111-118', '1998')
# ('A formal model for component-based system assessment', 'C Serban, A Vescan, HF Pop', '2010 Second International Conference on Computational Intelligence …', '2010')
# ('An adaptive fuzzy agent clustering algorithm for search engines', 'RD Gaceanu, HF Pop', 'MACS2010: Proceedings of the 8th Joint Conference on Mathematics and …', '2010')
# ('A study of licence examination results using Fuzzy Clustering techniques', 'M Frentiu, HF Pop', 'Babes-Bolyai University, Faculty of Mathematics and Computer Science …', '2001')
# ('Fuzzy classification of the first 10 MEIC', 'C Sârbu, H Pop', 'Chemosphere 40 (513), e520', '2000')
# ('Fuzzy regression. II. Outliers cases', 'HF Pop, C Sârbu', 'Revista de Chimie 48 (10-11), 888-891', '1997')
# ('SAADI: Software for fuzzy clustering and related fields', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Informatica 41 (1), 69-80', '1996')
# ('Recognizing Emotions in Short Texts.', 'O Serban, A Pauchet, HF Pop', 'ICAART (1), 477-480', '2012')
# ('An incremental ASM-based fuzzy clustering algorithm', 'RD Gaceanu, HF Pop', 'Informatics, 198-204', '2011')
# ('A context-aware ASM-based clustering algorithm', 'RD GACEANU, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 56 (2), 55-61', '2011')
# ('Automatic configuration for the component selection problem', 'A Vescan, HF Pop', 'Proceedings of the 5th international conference on Soft computing as …', '2008')
# ('Component selection based on fuzzy clustering analysis', 'C Serban, A Vescan, HF Pop', 'Creative Mathematics and Informatics 17 (3), 505-510', '2008')
# ('On Individual Projects in Software Engineering Education', 'M Frentiu, I Lazar, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 48 (2), 83-94', '2003')
# ('Development of robust fuzzy regression techniques using a fuzzy clustering approach', 'HF Pop', 'Pure Mathematics and Applications 14 (3), 221-232', '2003')
# ('Fuzzy classification and comparison of some Romanian and American coals', 'C Sârbu, HF Pop', 'MATCH-Communications in Mathematical and in Computer Chemistry, 387-400', '2001')
# ('Fuzzy regression. 1. The heteroscedastic case', 'C Sârbu, H Pop', 'REVISTA DE CHIMIE 48 (8), 732-737', '1997')
# ('DISCOVERING PATTERNS IN DATA USING ORDINAL DATA ANALYSIS.', 'AM COROIU, RD GĂCEANU, HF POP', 'Studia Universitatis Babes-Bolyai, Informatica 61 (1)', '2016')
# ('Prognostic Factors in Liver Failure in Children by Discriminant Analysis of Clinical Data. A Chemometric Approach', 'HF Pop, C Sarbu, A Stefanescu, A Bizo, TL Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI CHEMIA 60 (2), 101-108', '2015')
# ('Constraint optimization-based component selection problem', 'A Vescan, HF Pop', 'Studia Univ, Babes-Bolyai, Informatica 53 (2)', '2008')
# ('Education for engineering students-The case of logic', 'H Pop, L Pop', 'Proceedings 6th International Conference on Electromechanical and Power …', '2007')
# ('Tracking mistakes in software measurement using fuzzy data analysis', 'HF Pop, M Frenţiu', 'The 4-th International Conference RoEduNet Romania (Sovata, Târgu-Mures, 150-157', '2005')
# ('Sisteme inteligente în probleme de clasificare', 'HF Pop', 'Mediamira', '2004')
# ('Programare în inteligenţa artificială: LISP si PROLOG', 'HF Pop, G Şerban', 'Editura Albastră', '2003')
# ('Rational Classification of the Chemical Elements', 'O Horovitz, C Sârbu, HF Pop', 'Dacia Publisher House, Cluj-Napoca', '2000')
# ('Classification procedure for selectivity control in acrylonitrile electroreduction', 'DA Lowy, D Dumitrescu, L Oniciu, HF Pop, S Kiss-Szetsi', 'The 7th International Forum Process Analytical Chemistry (Process Analysis …', '1993')
# ('Improving movement analysis in physical therapy systems based on kinect interaction', 'AD Călin, H F. Pop, R F. Boian', 'Proceedings of the 31st International BCS Human Computer Interaction …', '2017')
# ('A fuzzy incremental clustering approach to hybrid data discovery', 'RD Gaceanu, HF Pop', 'Acta electrotechnica et informatica 12 (2), 16', '2012')
# ('An incremental approach to the set covering problem', 'RD Gaceanu, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 47 (2), 61-72', '2012')
# ('AP041 Joining the EuReCA–The Romanian Registry on Cardiac arrest–a year later', 'H Sabau, O Tudorache, H Pop, V Georgescu, V Strambu, I Dimitriu, ...', 'Resuscitation 82, S19', '2011')
# ('A fuzzy clustering algorithm for dynamic environments', 'RD Gaceanu, HF POP', 'KEPT2011: Knowledge Engineering Principles and Techniques, Selected Papers …', '2011')
# ('Romanian registry on cardiac arrest—A piece in the puzzle-Romanian contribution in the EuReCA project', 'V Georgescu, H Pop, O Tudorache, H Sabau, C Ciontu, I Dimitriu, ...', 'Resuscitation 81 (2), S39', '2010')
# ('Effort Estimation by Analogy based on Soft Computing Methods, KEPT2009: Knowledge Engineering: Principles and Techniques, Selected Papers', 'HF Pop, M Frenţiu', 'Cluj University Press, Cluj-Napoca', '2009')
# ('A New Component Selection Algorithm Based on Metrics and Fuzzy Clustering', 'C Serban, A Vescan, HF Pop', 'Creative Mathematics and Informatics 1 (3), 505-510', '2009')
# ('Fundamentals of Programming', 'M Frenţiu, HF Pop', 'Cluj University Press', '2006')
# ('Improving Virtual Team Performance: An Empirical Approach', 'D Radoiu, C Enachescu, HF Pop', 'A research paper of Sysgenic Sourcing, Available at sourcing. sysgenic. com …', '2006')
# ('Supervised fuzzy classifiers', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Mathematica 40 (3), 89-100', '1995')
# ('OPTIMUM SELECTIONS AND COMBINATION OF SOLVENT SYSTEMS IN THIN-LAYER CHROMATOGRAPHY, USING THE FUZZY SET-THEORY', 'C Sârbu, D Dumitrescu, H Pop', 'Revista de Chimie 44 (5), 450-459', '1993')
# ('Preliminary measurements in identifying design flaws', 'C SERBAN, A VESCAN, HF POP', 'Studia Universitatis Babes-Bolyai, Series Informatica 62 (1), 60-74', '2017')
# ('AN AGENT BASED APPROACH FOR PARALLEL CONSTRAINT VERIFICATION', 'RD Gaceanu, HF Pop, SA Sotoc', 'Studia Universitatis Babes-Bolyai, Series Informatica 58 (3), 5-16', '2013')
# ('An agent based approach for parallel constraint verification', 'RD Gaceanu, HF Pop, SA SOTOC', 'Studia Universitatis Babes-Bolyai Series Informatica 58 (3), 5-16', '2013')
# ('Stereomatching using radiometric invariant measures', 'A Miron, S Ainouz, A Rogozan, A Bensrhair, HF POP', 'UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 91', '2011')
# ('Improving similarity join algorithms using fuzzy clustering technique', 'L Tan, F Fotouhi, W Grosky, HF Pop, N Mouaddib', '2009 IEEE International Conference on Data Mining Workshops, 545-550', '2009')
# ('OVERVIEW OF FUZZY METHODS FOR EFFORT ESTIMATION BY ANALOGY.', 'M Frenţiu, HF Pop', 'Studia Universitatis Babes-Bolyai, Informatica', '2009')
# ('Lighting quality-component of indoor environment', 'F Pop, HF Pop, M Pop', 'LUX Eur, 499-506', '2009')
# ('Applications of principal components methods', 'HF Pop, M Frentiu', '2008 First International Conference on Complexity and Intelligence of the …', '2008')
# ('Programming Fundamentals', 'M Frenţiu, HF Pop, G Şerban', 'Presa Universitară Clujeană', '2006')
# ('Distance Learning and Supporting Tools at Babeş-Bolyai University', 'FM Boian, RF Boian, A Vancea, HF Pop', '1', '')
# ('CHARACTERIZATION AND CLASSIFICATION OF MEDICINAL PLANT EXTRACTS ACCORDING TO THEIR ANTIOXIDANT ACTIVITY USING HIGH-PERFORMANCE LIQUID CHROMATOGRAPHY AND MULTIVARIATE ANALYSIS.', 'IM Simion, AC MOȚ, RD GĂCEANU, HF Pop, C Sarbu', 'Studia Universitatis Babes-Bolyai, Chemia 65 (1)', '2020')
# ('A Comparison Study of Similarity Measures in Rough Sets Clustering', 'A Szederjesi-Dragomir, RD Găceanu, HF Pop, C Sârbu', '2019 IEEE 15th International Scientific Conference on Informatics, 000037-000042', '2019')
# ('A Machine Learning Perspective for Order Reduction in Electrical Motors Modeling', 'M Nutu, HF Pop, C Martis, SI Cosman, AM Nicorici', '2019 21st International Symposium on Symbolic and Numeric Algorithms for …', '2019')
# ('Principal Component Analysis for Computation of the Magnetization Characteristics of Synchronous Reluctance Machine', 'M Nutu, R Martis, HF Pop, C Martis', '2018 AEIT International Annual Conference, 1-6', '2018')
# ('SPECTROPHOTOMETRIC CHARACTERIZATION OF ROUMANIAN MEDICINAL HERBS ASSISTED BY ROBUST CHEMOMETRICS EXPERTISE', 'IM Simion, HF POPb, C Sarbu', 'Rev. Roum. Chim 63 (5-6), 489-496', '2018')
# ('The Best Writing on Mathematics 2015', 'HF Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 61 (1), 123-124', '2016')
# ('PROGNOSTIC FACTORS IN LIVER FAILURE IN CHILDREN BY DISCRIMINANT ANALYSIS OF CLINICAL DATA. A CHEMOMETRIC APPROACH.', 'C SÂRBU, A BIZO, TL POP, HF POP, ANA ŞTEFANESCU', 'Studia Universitatis Babes-Bolyai, Chemia 60', '2015')
# ('The Best Writing on Mathematics 2014', 'HF Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 59 (3), 393-394', '2014')
# ('Medical procedure breaches detection using a fuzzy clustering approach', 'R Găceanu, H Pop', 'Open Computer Science 4 (3), 127-140', '2014')
# ('An incremental clustering approach to the set covering problem', 'RD Gaceanu, HF Pop', 'Zoltán Csörnyei (Ed.), 45', '2012')
# ('Automatic criteria-based configuration for the component selection problem', 'A Vescan, HF Pop', 'International Journal of Computer Information Systems and Industrial …', '2012')
# ('Recent developments in fuzzy statistical analysis', 'HF Pop', 'MaCS’10, 47', '2010')
# ('PROCESSING ECG DATA USING MULTIVARIATE DATA ANALYSIS', 'MV PUŞCĂ, HF POP, NM ROMAN, V IANCU', 'ACADEMY OF ROMANIAN SCIENTISTS, 23', '2010')
# ('M. Effort estimation by analogy based on soft computing methods', 'HF POP, M FRENTIU', 'KEPT 2009 International Conference Knowledge Engineering Principles and …', '2009')
# ('Knowledge Engineering: Principles and Techniques: KEPT 2009: Cluj-Napoca, July 2-4, 2009', 'M Frențiu, HF Pop', 'Cluj University Press', '2009')
# ('Iluminat eficient energetic în locuinţe', 'F Pop, D Beu, HF Pop, C Ciugudeanu', 'Revista Română de Informatică şi Automatică 18 (3), 101-112', '2008')
# ('A Tutorial on Object-Oriented Functional Programming', 'HF Pop', 'Central European Functional Programming School, 228-249', '2007')
# ('ON SOFTWARE ATTRIBUTES RELATIONSHIP USING A NEW FUZZY C-BIPARTITIONING METHOD', 'HF Pop, M Frentiu', 'Studia Universitatis Babes-Bolyai, Informatica Special Issue, 219-226', '2007')
# ('Management of web pages using XML documents', 'L T ÂMBULEA, HF POP', 'Studia Universitatis Babes-Bolyai, Informatica Special Issue, 236-243', '2007')
# ('Desired employment/Occupational field', 'N Italian, G Male', 'Cell 39, 081678652', '2003')
# ('Appraisal of indoor lighting systems quality', 'M POP, HF POP, F POP', 'Ingineria Iluminatului, 37', '2001')
# ('Papers from the 1999 Symposium on Mathematical Chemistry, Duluth, MN, May 1999-MOLECULAR MODELING-Structural Analysis of Transition Metal bX Substituent Interactions. Toward …', 'TR Cundari, J Deng, HF Pop, C Sarbu', 'Journal of Chemical Information and Computer Sciences 40 (4), 1052-1061', '2000')
# ('Recognition of the forms applied to chemical elements', 'O Horowitz, C Sarbu, HF Pop', 'REVISTA DE CHIMIE 51 (1), 17-29', '2000')
# ('REGRESIE FUZZY. II. CAZUL PUNCTELOR EXTREME (OUTLIERS)', 'HF POP, C SARBU', 'Revista de chimie 48 (10-11), 888-891', '1997')
# ('REGRESIE FUZZY. I. CAZUL HETEROSCEDASTIC', 'C SARBU, H POP', 'Revista de chimie 48 (8), 732-737', '1997')
# ('Desired employment Occupational field', 'F Horia', 'Education and training 1995', '1992')
# ('KEPT2013: THE FOURTH INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING, PRINCIPLES AND TECHNIQUES', 'M FRENTIU, HF POP, S MOTOGNA', 'UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 5', '')
# ('Object-oriented logic programming', 'HF Pop, MM Dogaru', 'LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat', 'LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat')
# ('F Horia, POP Florin', 'SAADI: Software for Fuzzy Clustering and Related Fields', 'F Horia', 'F Horia')
# ('Residential Energy Efficient Lighting', 'POP Florin, F Horia', 'A guide for writing a scientific paper', 'A guide for writing a scientific paper')
# ('M Frenţiu, HF Pop', 'Metode de recunoastere a formelor bazate pe agenti', 'UBB Îndrumator, HF Pop', 'UBB Îndrumator, HF Pop')
# ('THE FIRST INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING PRINCIPLES AND TECHNIQUES (KEPT 2007)', 'D TATAR, HF Pop, M FRENTIU, D Dumitrescu', 'COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER', 'COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER')

# %%
for i, paper in enumerate(mylines):
    print(i, paper[0])
errors_index = [113, 111]
# Out:
# 0 Principal component analysis versus fuzzy principal component analysis: a case study: the quality of Danube water (1985–1996)
# 1 Robust Fuzzy Principal Component Analysis (FPCA). A Comparative Study Concerning Interaction of Carbon− Hydrogen Bonds with Molybdenum− Oxo Bonds
# 2 A new fuzzy regression algorithm
# 3 Introducere în algoritmi
# 4 A fuzzy classification of the chemical elements
# 5 Fuzzy soft-computing methods and their applications in chemistry
# 6 A fuzzy divisive hierarchical clustering algorithm for the optimal choice of sets of solvent systems
# 7 Classical and fuzzy principal component analysis of some environmental samples concerning the pollution with heavy metals
# 8 Structural Analysis of Transition Metal β-X Substituent Interactions. Toward the Use of Soft Computing Methods for Catalyst Modeling
# 9 A study of Roman pottery (terra sigillata) using hierarchical fuzzy clustering
# 10 Principal components analysis based on a fuzzy sets approach
# 11 Learning grammar weights using genetic algorithms
# 12 Fuzzy clustering analysis of the first 10 MEIC chemicals
# 13 A new component selection algorithm based on metrics and fuzzy clustering analysis
# 14 The fuzzy hierarchical cross-clustering algorithm. Improvements and comparative study
# 15 Fuzzy robust estimation of central location
# 16 A Fuzzy cross-classification of the chemical elements, based on their physical, chemical, and structural features
# 17 Fuzzy hierarchical cross-classification of Greek muds
# 18 GFBA: a biclustering algorithm for discovering value-coherent biclusters
# 19 Degenerate and non-degenerate convex decomposition of finite fuzzy partitions—I
# 20 Data analysis with fuzzy sets: a short survey
# 21 A study of dependence of software attributes using data analysis techniques
# 22 Selecting and optimally combining the systems of solvents in the thin film cromatography using the fuzzy sets theory
# 23 Software quality assessment using a fuzzy clustering approach
# 24 Evolutionary algorithms for the component selection problem
# 25 Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti
# 26 Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti
# 27 An experiment on incremental analysis using robust parsing techniques
# 28 Intelligent Systems in Classification Problems
# 29 A conceptual framework for component-based system metrics definition
# 30 Intelligent disease identification based on discriminant analysis of clinical data
# 31 The component selection problem as a constraint optimization problem
# 32 Learning weights for a natural language grammar using genetic algorithms
# 33 Assessment of heart disease using fuzzy classification techniques
# 34 A new fuzzy discriminant analysis method
# 35 An experiment in incremental parsing using weighted constraints
# 36 Degenerate and non-degenerate convex decomposition of finite fuzzy partitions (II)
# 37 A formal model for component-based system assessment
# 38 An adaptive fuzzy agent clustering algorithm for search engines
# 39 A study of licence examination results using Fuzzy Clustering techniques
# 40 Fuzzy classification of the first 10 MEIC
# 41 Fuzzy regression. II. Outliers cases
# 42 SAADI: Software for fuzzy clustering and related fields
# 43 Recognizing Emotions in Short Texts.
# 44 An incremental ASM-based fuzzy clustering algorithm
# 45 A context-aware ASM-based clustering algorithm
# 46 Automatic configuration for the component selection problem
# 47 Component selection based on fuzzy clustering analysis
# 48 On Individual Projects in Software Engineering Education
# 49 Development of robust fuzzy regression techniques using a fuzzy clustering approach
# 50 Fuzzy classification and comparison of some Romanian and American coals
# 51 Fuzzy regression. 1. The heteroscedastic case
# 52 DISCOVERING PATTERNS IN DATA USING ORDINAL DATA ANALYSIS.
# 53 Prognostic Factors in Liver Failure in Children by Discriminant Analysis of Clinical Data. A Chemometric Approach
# 54 Constraint optimization-based component selection problem
# 55 Education for engineering students-The case of logic
# 56 Tracking mistakes in software measurement using fuzzy data analysis
# 57 Sisteme inteligente în probleme de clasificare
# 58 Programare în inteligenţa artificială: LISP si PROLOG
# 59 Rational Classification of the Chemical Elements
# 60 Classification procedure for selectivity control in acrylonitrile electroreduction
# 61 Improving movement analysis in physical therapy systems based on kinect interaction
# 62 A fuzzy incremental clustering approach to hybrid data discovery
# 63 An incremental approach to the set covering problem
# 64 AP041 Joining the EuReCA–The Romanian Registry on Cardiac arrest–a year later
# 65 A fuzzy clustering algorithm for dynamic environments
# 66 Romanian registry on cardiac arrest—A piece in the puzzle-Romanian contribution in the EuReCA project
# 67 Effort Estimation by Analogy based on Soft Computing Methods, KEPT2009: Knowledge Engineering: Principles and Techniques, Selected Papers
# 68 A New Component Selection Algorithm Based on Metrics and Fuzzy Clustering
# 69 Fundamentals of Programming
# 70 Improving Virtual Team Performance: An Empirical Approach
# 71 Supervised fuzzy classifiers
# 72 OPTIMUM SELECTIONS AND COMBINATION OF SOLVENT SYSTEMS IN THIN-LAYER CHROMATOGRAPHY, USING THE FUZZY SET-THEORY
# 73 Preliminary measurements in identifying design flaws
# 74 AN AGENT BASED APPROACH FOR PARALLEL CONSTRAINT VERIFICATION
# 75 An agent based approach for parallel constraint verification
# 76 Stereomatching using radiometric invariant measures
# 77 Improving similarity join algorithms using fuzzy clustering technique
# 78 OVERVIEW OF FUZZY METHODS FOR EFFORT ESTIMATION BY ANALOGY.
# 79 Lighting quality-component of indoor environment
# 80 Applications of principal components methods
# 81 Programming Fundamentals
# 82 Distance Learning and Supporting Tools at Babeş-Bolyai University
# 83 CHARACTERIZATION AND CLASSIFICATION OF MEDICINAL PLANT EXTRACTS ACCORDING TO THEIR ANTIOXIDANT ACTIVITY USING HIGH-PERFORMANCE LIQUID CHROMATOGRAPHY AND MULTIVARIATE ANALYSIS.
# 84 A Comparison Study of Similarity Measures in Rough Sets Clustering
# 85 A Machine Learning Perspective for Order Reduction in Electrical Motors Modeling
# 86 Principal Component Analysis for Computation of the Magnetization Characteristics of Synchronous Reluctance Machine
# 87 SPECTROPHOTOMETRIC CHARACTERIZATION OF ROUMANIAN MEDICINAL HERBS ASSISTED BY ROBUST CHEMOMETRICS EXPERTISE
# 88 The Best Writing on Mathematics 2015
# 89 PROGNOSTIC FACTORS IN LIVER FAILURE IN CHILDREN BY DISCRIMINANT ANALYSIS OF CLINICAL DATA. A CHEMOMETRIC APPROACH.
# 90 The Best Writing on Mathematics 2014
# 91 Medical procedure breaches detection using a fuzzy clustering approach
# 92 An incremental clustering approach to the set covering problem
# 93 Automatic criteria-based configuration for the component selection problem
# 94 Recent developments in fuzzy statistical analysis
# 95 PROCESSING ECG DATA USING MULTIVARIATE DATA ANALYSIS
# 96 M. Effort estimation by analogy based on soft computing methods
# 97 Knowledge Engineering: Principles and Techniques: KEPT 2009: Cluj-Napoca, July 2-4, 2009
# 98 Iluminat eficient energetic în locuinţe
# 99 A Tutorial on Object-Oriented Functional Programming
# 100 ON SOFTWARE ATTRIBUTES RELATIONSHIP USING A NEW FUZZY C-BIPARTITIONING METHOD
# 101 Management of web pages using XML documents
# 102 Desired employment/Occupational field
# 103 Appraisal of indoor lighting systems quality
# 104 Papers from the 1999 Symposium on Mathematical Chemistry, Duluth, MN, May 1999-MOLECULAR MODELING-Structural Analysis of Transition Metal bX Substituent Interactions. Toward …
# 105 Recognition of the forms applied to chemical elements
# 106 REGRESIE FUZZY. II. CAZUL PUNCTELOR EXTREME (OUTLIERS)
# 107 REGRESIE FUZZY. I. CAZUL HETEROSCEDASTIC
# 108 Desired employment Occupational field
# 109 KEPT2013: THE FOURTH INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING, PRINCIPLES AND TECHNIQUES
# 110 Object-oriented logic programming
# 111 F Horia, POP Florin
# 112 Residential Energy Efficient Lighting
# 113 M Frenţiu, HF Pop
# 114 THE FIRST INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING PRINCIPLES AND TECHNIQUES (KEPT 2007)

# %%
for i, paper in enumerate(mylines):
    if i in errors_index:
        print(i, paper)
        #mylines[i][0] = mylines[i][1]
# Out:
# 111 ('F Horia, POP Florin', 'SAADI: Software for Fuzzy Clustering and Related Fields', 'F Horia', 'F Horia')
# 113 ('M Frenţiu, HF Pop', 'Metode de recunoastere a formelor bazate pe agenti', 'UBB Îndrumator, HF Pop', 'UBB Îndrumator, HF Pop')

# %% [markdown]
# # DB Storage (TODO)
# Time to store the entries in the `papers` DB table.

# %% [markdown]
# ![Screenshot](Images/PapersTableSpec.PNG)

# %%
import mariadb
import json

# %%
with open('../credentials.json', 'r') as crd_json_fd:
    json_text = crd_json_fd.read()
    json_obj = json.loads(json_text)

# %%
credentials = json_obj["Credentials"]
username = credentials["username"]
password = credentials["password"]

# %%
table_name = "publications_cache"
db_name = "ubbcluj"

# %%
mariadb_connection = mariadb.connect(user=username, password=password, database=db_name)
mariadb_cursor = mariadb_connection.cursor()

# %%
for paper in mylines:
    
    title = ""
    authors = ""
    pub_date = ""
    affiliations = ""
    
    try:
        title = paper[0].lstrip()
    except:
        pass
    
    try:
        authors = paper[1].lstrip()
    except:
        pass
        
    try:
        affiliations = paper[2].lstrip()
    except AttributeError:
        pass
    
    try:
        pub_date = paper[3].lstrip()
        pub_date = str(pub_date) + "-01-01"
        if len(pub_date) != 10:
            pub_date = ""
    except:
        pass
    
    insert_string = "INSERT INTO {0} SET ".format(table_name)
    insert_string += "Title=\'{0}\', ".format(title)
    insert_string += "ProfessorId=\'{0}\', ".format(5)
    if pub_date != "":
        insert_string += "PublicationDate=\'{0}\', ".format(str(pub_date))
    insert_string += "Authors=\'{0}\', ".format(authors)
    insert_string += "Affiliations=\'{0}\' ".format(affiliations)
    print(insert_string)
    print(paper)
    
    try:
        mariadb_cursor.execute(insert_string)
    except mariadb.ProgrammingError as pe:
        print("Error")
        raise pe
    except mariadb.IntegrityError:
        continue
# Out:
# INSERT INTO publications_cache SET Title='Principal component analysis versus fuzzy principal component analysis: a case study: the quality of Danube water (1985–1996)', ProfessorId='5', PublicationDate='2005-01-01', Authors='C Sarbu, HF Pop', Affiliations='Talanta 65 (5), 1215-1220'
# ('Principal component analysis versus fuzzy principal component analysis: a case study: the quality of Danube water (1985–1996)', 'C Sarbu, HF Pop', 'Talanta 65 (5), 1215-1220', '2005')
# INSERT INTO publications_cache SET Title='Robust Fuzzy Principal Component Analysis (FPCA). A Comparative Study Concerning Interaction of Carbon− Hydrogen Bonds with Molybdenum− Oxo Bonds', ProfessorId='5', PublicationDate='2002-01-01', Authors='TR Cundari, C Sârbu, HF Pop', Affiliations='Journal of chemical information and computer sciences 42 (6), 1363-1369'
# ('Robust Fuzzy Principal Component Analysis (FPCA). A Comparative Study Concerning Interaction of Carbon− Hydrogen Bonds with Molybdenum− Oxo Bonds', 'TR Cundari, C Sârbu, HF Pop', 'Journal of chemical information and computer sciences 42 (6), 1363-1369', '2002')
# INSERT INTO publications_cache SET Title='A new fuzzy regression algorithm', ProfessorId='5', PublicationDate='1996-01-01', Authors='HF Pop, C Sârbu', Affiliations='Analytical chemistry 68 (5), 771-778'
# ('A new fuzzy regression algorithm', 'HF Pop, C Sârbu', 'Analytical chemistry 68 (5), 771-778', '1996')
# INSERT INTO publications_cache SET Title='Introducere în algoritmi', ProfessorId='5', PublicationDate='2004-01-01', Authors='TH Cormen, CE Leiserson, RR Rivest, HF Pop, S Motogna, PA Blaga', Affiliations='Computer Libris Agora'
# ('Introducere în algoritmi', 'TH Cormen, CE Leiserson, RR Rivest, HF Pop, S Motogna, PA Blaga', 'Computer Libris Agora', '2004')
# INSERT INTO publications_cache SET Title='A fuzzy classification of the chemical elements', ProfessorId='5', PublicationDate='1996-01-01', Authors='HF Pop, C Sârbu, O Horowitz, D Dumitrescu', Affiliations='Journal of chemical information and computer sciences 36 (3), 465-482'
# ('A fuzzy classification of the chemical elements', 'HF Pop, C Sârbu, O Horowitz, D Dumitrescu', 'Journal of chemical information and computer sciences 36 (3), 465-482', '1996')
# INSERT INTO publications_cache SET Title='Fuzzy soft-computing methods and their applications in chemistry', ProfessorId='5', PublicationDate='2004-01-01', Authors='C Sârbu, HF Pop', Affiliations='Reviews in Computational Chemistry 20, 249'
# ('Fuzzy soft-computing methods and their applications in chemistry', 'C Sârbu, HF Pop', 'Reviews in Computational Chemistry 20, 249', '2004')
# INSERT INTO publications_cache SET Title='A fuzzy divisive hierarchical clustering algorithm for the optimal choice of sets of solvent systems', ProfessorId='5', PublicationDate='1994-01-01', Authors='D Dumitrescu, C S [acaron] rbu, H Pop', Affiliations='Analytical letters 27 (5), 1031-1054'
# ('A fuzzy divisive hierarchical clustering algorithm for the optimal choice of sets of solvent systems', 'D Dumitrescu, C S [acaron] rbu, H Pop', 'Analytical letters 27 (5), 1031-1054', '1994')
# INSERT INTO publications_cache SET Title='Classical and fuzzy principal component analysis of some environmental samples concerning the pollution with heavy metals', ProfessorId='5', PublicationDate='2009-01-01', Authors='HF Pop, JW Einax, C Sârbu', Affiliations='Chemometrics and Intelligent Laboratory Systems 97 (1), 25-32'
# ('Classical and fuzzy principal component analysis of some environmental samples concerning the pollution with heavy metals', 'HF Pop, JW Einax, C Sârbu', 'Chemometrics and Intelligent Laboratory Systems 97 (1), 25-32', '2009')
# INSERT INTO publications_cache SET Title='Structural Analysis of Transition Metal β-X Substituent Interactions. Toward the Use of Soft Computing Methods for Catalyst Modeling', ProfessorId='5', PublicationDate='2000-01-01', Authors='TR Cundari, J Deng, HF Pop, C Sârbu', Affiliations='Journal of chemical information and computer sciences 40 (4), 1052-1061'
# ('Structural Analysis of Transition Metal β-X Substituent Interactions. Toward the Use of Soft Computing Methods for Catalyst Modeling', 'TR Cundari, J Deng, HF Pop, C Sârbu', 'Journal of chemical information and computer sciences 40 (4), 1052-1061', '2000')
# INSERT INTO publications_cache SET Title='A study of Roman pottery (terra sigillata) using hierarchical fuzzy clustering', ProfessorId='5', PublicationDate='1995-01-01', Authors='HF Pop, D Dumitrescu, C Sǎrbu', Affiliations='Analytica chimica acta 310 (2), 269-279'
# ('A study of Roman pottery (terra sigillata) using hierarchical fuzzy clustering', 'HF Pop, D Dumitrescu, C Sǎrbu', 'Analytica chimica acta 310 (2), 269-279', '1995')
# INSERT INTO publications_cache SET Title='Principal components analysis based on a fuzzy sets approach', ProfessorId='5', PublicationDate='2001-01-01', Authors='H Pop', Affiliations='Mij 1 (2), 1'
# ('Principal components analysis based on a fuzzy sets approach', 'H Pop', 'Mij 1 (2), 1', '2001')
# INSERT INTO publications_cache SET Title='Learning grammar weights using genetic algorithms', ProfessorId='5', PublicationDate='2001-01-01', Authors='I Schröder, HF Pop, W Menzel, KA Foth', Affiliations='IN PROCEEDINGS RECENT ADVANCES IN NATURAL LANGUAGE PROCESSING, RANLP-2001'
# ('Learning grammar weights using genetic algorithms', 'I Schröder, HF Pop, W Menzel, KA Foth', 'IN PROCEEDINGS RECENT ADVANCES IN NATURAL LANGUAGE PROCESSING, RANLP-2001', '2001')
# INSERT INTO publications_cache SET Title='Fuzzy clustering analysis of the first 10 MEIC chemicals', ProfessorId='5', PublicationDate='2000-01-01', Authors='C Sârbu, HF Pop', Affiliations='Chemosphere 40 (5), 513-520'
# ('Fuzzy clustering analysis of the first 10 MEIC chemicals', 'C Sârbu, HF Pop', 'Chemosphere 40 (5), 513-520', '2000')
# INSERT INTO publications_cache SET Title='A new component selection algorithm based on metrics and fuzzy clustering analysis', ProfessorId='5', PublicationDate='2009-01-01', Authors='C Şerban, A Vescan, HF Pop', Affiliations='International Conference on Hybrid Artificial Intelligence Systems, 621-628'
# ('A new component selection algorithm based on metrics and fuzzy clustering analysis', 'C Şerban, A Vescan, HF Pop', 'International Conference on Hybrid Artificial Intelligence Systems, 621-628', '2009')
# INSERT INTO publications_cache SET Title='The fuzzy hierarchical cross-clustering algorithm. Improvements and comparative study', ProfessorId='5', PublicationDate='1997-01-01', Authors='HF Pop, C Sârbu', Affiliations='Journal of chemical information and computer sciences 37 (3), 510-516'
# ('The fuzzy hierarchical cross-clustering algorithm. Improvements and comparative study', 'HF Pop, C Sârbu', 'Journal of chemical information and computer sciences 37 (3), 510-516', '1997')
# INSERT INTO publications_cache SET Title='Fuzzy robust estimation of central location', ProfessorId='5', PublicationDate='2001-01-01', Authors='C Sârbu, HF Pop', Affiliations='Talanta 54 (1), 125-130'
# ('Fuzzy robust estimation of central location', 'C Sârbu, HF Pop', 'Talanta 54 (1), 125-130', '2001')
# INSERT INTO publications_cache SET Title='A Fuzzy cross-classification of the chemical elements, based on their physical, chemical, and structural features', ProfessorId='5', PublicationDate='1996-01-01', Authors='C Sârbu, O Horowitz, HF Pop', Affiliations='Journal of chemical information and computer sciences 36 (6), 1098-1108'
# ('A Fuzzy cross-classification of the chemical elements, based on their physical, chemical, and structural features', 'C Sârbu, O Horowitz, HF Pop', 'Journal of chemical information and computer sciences 36 (6), 1098-1108', '1996')
# INSERT INTO publications_cache SET Title='Fuzzy hierarchical cross-classification of Greek muds', ProfessorId='5', PublicationDate='1995-01-01', Authors='D Dumitrescu, HF Pop, C Sarbu', Affiliations='Journal of chemical information and computer sciences 35 (5), 851-857'
# ('Fuzzy hierarchical cross-classification of Greek muds', 'D Dumitrescu, HF Pop, C Sarbu', 'Journal of chemical information and computer sciences 35 (5), 851-857', '1995')
# INSERT INTO publications_cache SET Title='GFBA: a biclustering algorithm for discovering value-coherent biclusters', ProfessorId='5', PublicationDate='2007-01-01', Authors='X Fei, S Lu, HF Pop, LR Liang', Affiliations='International Symposium on Bioinformatics Research and Applications, 1-12'
# ('GFBA: a biclustering algorithm for discovering value-coherent biclusters', 'X Fei, S Lu, HF Pop, LR Liang', 'International Symposium on Bioinformatics Research and Applications, 1-12', '2007')
# INSERT INTO publications_cache SET Title='Degenerate and non-degenerate convex decomposition of finite fuzzy partitions—I', ProfessorId='5', PublicationDate='1995-01-01', Authors='D Dumitrescu, HF Pop', Affiliations='Fuzzy sets and systems 73 (3), 365-376'
# ('Degenerate and non-degenerate convex decomposition of finite fuzzy partitions—I', 'D Dumitrescu, HF Pop', 'Fuzzy sets and systems 73 (3), 365-376', '1995')
# INSERT INTO publications_cache SET Title='Data analysis with fuzzy sets: a short survey', ProfessorId='5', PublicationDate='2004-01-01', Authors='HF Pop', Affiliations='Studia Universitatis Babes-Bolyai, Series Informatica 49 (2), 111-122'
# ('Data analysis with fuzzy sets: a short survey', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Informatica 49 (2), 111-122', '2004')
# INSERT INTO publications_cache SET Title='A study of dependence of software attributes using data analysis techniques', ProfessorId='5', PublicationDate='2002-01-01', Authors='M Frentiu, HF Pop', Affiliations='Studia Univ. Babes-Bolyai, Series Informatica 2, 53-66'
# ('A study of dependence of software attributes using data analysis techniques', 'M Frentiu, HF Pop', 'Studia Univ. Babes-Bolyai, Series Informatica 2, 53-66', '2002')
# INSERT INTO publications_cache SET Title='Selecting and optimally combining the systems of solvents in the thin film cromatography using the fuzzy sets theory', ProfessorId='5', PublicationDate='1993-01-01', Authors='C Sârbu, D Dumitrescu, HF Pop', Affiliations='Rev. Chim.(Bucharest) 44, 450-459'
# ('Selecting and optimally combining the systems of solvents in the thin film cromatography using the fuzzy sets theory', 'C Sârbu, D Dumitrescu, HF Pop', 'Rev. Chim.(Bucharest) 44, 450-459', '1993')
# INSERT INTO publications_cache SET Title='Software quality assessment using a fuzzy clustering approach', ProfessorId='5', PublicationDate='2008-01-01', Authors='C Serban, HF POP', Affiliations='Studia Universitas Babes-Bolyai, Seria Informatica 53 (2), 27-38'
# ('Software quality assessment using a fuzzy clustering approach', 'C Serban, HF POP', 'Studia Universitas Babes-Bolyai, Seria Informatica 53 (2), 27-38', '2008')
# INSERT INTO publications_cache SET Title='Evolutionary algorithms for the component selection problem', ProfessorId='5', PublicationDate='2008-01-01', Authors='A Vescan, C Grosan, HF Pop', Affiliations='2008 19th International workshop on database and expert systems applications …'
# ('Evolutionary algorithms for the component selection problem', 'A Vescan, C Grosan, HF Pop', '2008 19th International workshop on database and expert systems applications …', '2008')
# INSERT INTO publications_cache SET Title='Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', ProfessorId='5', PublicationDate='2004-01-01', Authors='G Serban, HF Pop', Affiliations='Ed. Mediamira, Cluj-Napoca'
# ('Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', 'G Serban, HF Pop', 'Ed. Mediamira, Cluj-Napoca', '2004')
# INSERT INTO publications_cache SET Title='Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', ProfessorId='5', PublicationDate='2004-01-01', Authors='G Serban, HF Pop', Affiliations='Ed. Mediamira, Cluj-Napoca'
# ('Tehnici de Inteligenta Artificiala. Abordari bazate pe Agenti Inteligenti', 'G Serban, HF Pop', 'Ed. Mediamira, Cluj-Napoca', '2004')
# INSERT INTO publications_cache SET Title='An experiment on incremental analysis using robust parsing techniques', ProfessorId='5', PublicationDate='2000-01-01', Authors='KA Foth, W Menzel, HF Pop, I Schroder', Affiliations='COLING 2000 Volume 2: The 18th International Conference on Computational …'
# ('An experiment on incremental analysis using robust parsing techniques', 'KA Foth, W Menzel, HF Pop, I Schroder', 'COLING 2000 Volume 2: The 18th International Conference on Computational …', '2000')
# INSERT INTO publications_cache SET Title='Intelligent Systems in Classification Problems', ProfessorId='5', PublicationDate='1995-01-01', Authors='HF Pop', Affiliations='Ph. D. thesis," Babeş-Bolyai" University, Faculty of Mathematics and …'
# ('Intelligent Systems in Classification Problems', 'HF Pop', 'Ph. D. thesis," Babeş-Bolyai" University, Faculty of Mathematics and …', '1995')
# INSERT INTO publications_cache SET Title='A conceptual framework for component-based system metrics definition', ProfessorId='5', PublicationDate='2010-01-01', Authors='C Şerban, A Vescan, HF Pop', Affiliations='9th RoEduNet IEEE International Conference, 73-78'
# ('A conceptual framework for component-based system metrics definition', 'C Şerban, A Vescan, HF Pop', '9th RoEduNet IEEE International Conference, 73-78', '2010')
# INSERT INTO publications_cache SET Title='Intelligent disease identification based on discriminant analysis of clinical data', ProfessorId='5', PublicationDate='2008-01-01', Authors='C Sarbu, HF Pop, R Elekes, G Covaci', Affiliations='Rev Chimie 59, 1237-1241'
# ('Intelligent disease identification based on discriminant analysis of clinical data', 'C Sarbu, HF Pop, R Elekes, G Covaci', 'Rev Chimie 59, 1237-1241', '2008')
# INSERT INTO publications_cache SET Title='The component selection problem as a constraint optimization problem', ProfessorId='5', PublicationDate='2008-01-01', Authors='A Vescan, HF Pop', Affiliations='Software Engineering Techniques in Progress, Wroclaw University of …'
# ('The component selection problem as a constraint optimization problem', 'A Vescan, HF Pop', 'Software Engineering Techniques in Progress, Wroclaw University of …', '2008')
# INSERT INTO publications_cache SET Title='Learning weights for a natural language grammar using genetic algorithms', ProfessorId='5', PublicationDate='2002-01-01', Authors='I Schröder, HF Pop, W Menzel, KA Foth', Affiliations='7'
# ('Learning weights for a natural language grammar using genetic algorithms', 'I Schröder, HF Pop, W Menzel, KA Foth', '7', '2002')
# INSERT INTO publications_cache SET Title='Assessment of heart disease using fuzzy classification techniques', ProfessorId='5', PublicationDate='2001-01-01', Authors='HF Pop, TL Pop, C Sârbu', Affiliations='TheScientificWorldJournal 1, 369-390'
# ('Assessment of heart disease using fuzzy classification techniques', 'HF Pop, TL Pop, C Sârbu', 'TheScientificWorldJournal 1, 369-390', '2001')
# INSERT INTO publications_cache SET Title='A new fuzzy discriminant analysis method', ProfessorId='5', PublicationDate='2013-01-01', Authors='HF Pop, C Sârbu', Affiliations='natural science (chemometrics, environmental sciences, biology, geology, etc …'
# ('A new fuzzy discriminant analysis method', 'HF Pop, C Sârbu', 'natural science (chemometrics, environmental sciences, biology, geology, etc …', '2013')
# INSERT INTO publications_cache SET Title='An experiment in incremental parsing using weighted constraints', ProfessorId='5', PublicationDate='2000-01-01', Authors='K Foth, W Menzel, HF Pop, I Schröder', Affiliations='Proceedings of the 18th International Conference on Computational …'
# ('An experiment in incremental parsing using weighted constraints', 'K Foth, W Menzel, HF Pop, I Schröder', 'Proceedings of the 18th International Conference on Computational …', '2000')
# INSERT INTO publications_cache SET Title='Degenerate and non-degenerate convex decomposition of finite fuzzy partitions (II)', ProfessorId='5', PublicationDate='1998-01-01', Authors='D Dumitrescu, HF Pop', Affiliations='Fuzzy sets and systems 96 (1), 111-118'
# ('Degenerate and non-degenerate convex decomposition of finite fuzzy partitions (II)', 'D Dumitrescu, HF Pop', 'Fuzzy sets and systems 96 (1), 111-118', '1998')
# INSERT INTO publications_cache SET Title='A formal model for component-based system assessment', ProfessorId='5', PublicationDate='2010-01-01', Authors='C Serban, A Vescan, HF Pop', Affiliations='2010 Second International Conference on Computational Intelligence …'
# ('A formal model for component-based system assessment', 'C Serban, A Vescan, HF Pop', '2010 Second International Conference on Computational Intelligence …', '2010')
# INSERT INTO publications_cache SET Title='An adaptive fuzzy agent clustering algorithm for search engines', ProfessorId='5', PublicationDate='2010-01-01', Authors='RD Gaceanu, HF Pop', Affiliations='MACS2010: Proceedings of the 8th Joint Conference on Mathematics and …'
# ('An adaptive fuzzy agent clustering algorithm for search engines', 'RD Gaceanu, HF Pop', 'MACS2010: Proceedings of the 8th Joint Conference on Mathematics and …', '2010')
# INSERT INTO publications_cache SET Title='A study of licence examination results using Fuzzy Clustering techniques', ProfessorId='5', PublicationDate='2001-01-01', Authors='M Frentiu, HF Pop', Affiliations='Babes-Bolyai University, Faculty of Mathematics and Computer Science …'
# ('A study of licence examination results using Fuzzy Clustering techniques', 'M Frentiu, HF Pop', 'Babes-Bolyai University, Faculty of Mathematics and Computer Science …', '2001')
# INSERT INTO publications_cache SET Title='Fuzzy classification of the first 10 MEIC', ProfessorId='5', PublicationDate='2000-01-01', Authors='C Sârbu, H Pop', Affiliations='Chemosphere 40 (513), e520'
# ('Fuzzy classification of the first 10 MEIC', 'C Sârbu, H Pop', 'Chemosphere 40 (513), e520', '2000')
# INSERT INTO publications_cache SET Title='Fuzzy regression. II. Outliers cases', ProfessorId='5', PublicationDate='1997-01-01', Authors='HF Pop, C Sârbu', Affiliations='Revista de Chimie 48 (10-11), 888-891'
# ('Fuzzy regression. II. Outliers cases', 'HF Pop, C Sârbu', 'Revista de Chimie 48 (10-11), 888-891', '1997')
# INSERT INTO publications_cache SET Title='SAADI: Software for fuzzy clustering and related fields', ProfessorId='5', PublicationDate='1996-01-01', Authors='HF Pop', Affiliations='Studia Universitatis Babes-Bolyai, Series Informatica 41 (1), 69-80'
# ('SAADI: Software for fuzzy clustering and related fields', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Informatica 41 (1), 69-80', '1996')
# INSERT INTO publications_cache SET Title='Recognizing Emotions in Short Texts.', ProfessorId='5', PublicationDate='2012-01-01', Authors='O Serban, A Pauchet, HF Pop', Affiliations='ICAART (1), 477-480'
# ('Recognizing Emotions in Short Texts.', 'O Serban, A Pauchet, HF Pop', 'ICAART (1), 477-480', '2012')
# INSERT INTO publications_cache SET Title='An incremental ASM-based fuzzy clustering algorithm', ProfessorId='5', PublicationDate='2011-01-01', Authors='RD Gaceanu, HF Pop', Affiliations='Informatics, 198-204'
# ('An incremental ASM-based fuzzy clustering algorithm', 'RD Gaceanu, HF Pop', 'Informatics, 198-204', '2011')
# INSERT INTO publications_cache SET Title='A context-aware ASM-based clustering algorithm', ProfessorId='5', PublicationDate='2011-01-01', Authors='RD GACEANU, HF Pop', Affiliations='Studia Universitatis Babes-Bolyai Series Informatica 56 (2), 55-61'
# ('A context-aware ASM-based clustering algorithm', 'RD GACEANU, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 56 (2), 55-61', '2011')
# INSERT INTO publications_cache SET Title='Automatic configuration for the component selection problem', ProfessorId='5', PublicationDate='2008-01-01', Authors='A Vescan, HF Pop', Affiliations='Proceedings of the 5th international conference on Soft computing as …'
# ('Automatic configuration for the component selection problem', 'A Vescan, HF Pop', 'Proceedings of the 5th international conference on Soft computing as …', '2008')
# INSERT INTO publications_cache SET Title='Component selection based on fuzzy clustering analysis', ProfessorId='5', PublicationDate='2008-01-01', Authors='C Serban, A Vescan, HF Pop', Affiliations='Creative Mathematics and Informatics 17 (3), 505-510'
# ('Component selection based on fuzzy clustering analysis', 'C Serban, A Vescan, HF Pop', 'Creative Mathematics and Informatics 17 (3), 505-510', '2008')
# INSERT INTO publications_cache SET Title='On Individual Projects in Software Engineering Education', ProfessorId='5', PublicationDate='2003-01-01', Authors='M Frentiu, I Lazar, HF Pop', Affiliations='Studia Universitatis Babes-Bolyai Series Informatica 48 (2), 83-94'
# ('On Individual Projects in Software Engineering Education', 'M Frentiu, I Lazar, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 48 (2), 83-94', '2003')
# INSERT INTO publications_cache SET Title='Development of robust fuzzy regression techniques using a fuzzy clustering approach', ProfessorId='5', PublicationDate='2003-01-01', Authors='HF Pop', Affiliations='Pure Mathematics and Applications 14 (3), 221-232'
# ('Development of robust fuzzy regression techniques using a fuzzy clustering approach', 'HF Pop', 'Pure Mathematics and Applications 14 (3), 221-232', '2003')
# INSERT INTO publications_cache SET Title='Fuzzy classification and comparison of some Romanian and American coals', ProfessorId='5', PublicationDate='2001-01-01', Authors='C Sârbu, HF Pop', Affiliations='MATCH-Communications in Mathematical and in Computer Chemistry, 387-400'
# ('Fuzzy classification and comparison of some Romanian and American coals', 'C Sârbu, HF Pop', 'MATCH-Communications in Mathematical and in Computer Chemistry, 387-400', '2001')
# INSERT INTO publications_cache SET Title='Fuzzy regression. 1. The heteroscedastic case', ProfessorId='5', PublicationDate='1997-01-01', Authors='C Sârbu, H Pop', Affiliations='REVISTA DE CHIMIE 48 (8), 732-737'
# ('Fuzzy regression. 1. The heteroscedastic case', 'C Sârbu, H Pop', 'REVISTA DE CHIMIE 48 (8), 732-737', '1997')
# INSERT INTO publications_cache SET Title='DISCOVERING PATTERNS IN DATA USING ORDINAL DATA ANALYSIS.', ProfessorId='5', PublicationDate='2016-01-01', Authors='AM COROIU, RD GĂCEANU, HF POP', Affiliations='Studia Universitatis Babes-Bolyai, Informatica 61 (1)'
# ('DISCOVERING PATTERNS IN DATA USING ORDINAL DATA ANALYSIS.', 'AM COROIU, RD GĂCEANU, HF POP', 'Studia Universitatis Babes-Bolyai, Informatica 61 (1)', '2016')
# INSERT INTO publications_cache SET Title='Prognostic Factors in Liver Failure in Children by Discriminant Analysis of Clinical Data. A Chemometric Approach', ProfessorId='5', PublicationDate='2015-01-01', Authors='HF Pop, C Sarbu, A Stefanescu, A Bizo, TL Pop', Affiliations='STUDIA UNIVERSITATIS BABES-BOLYAI CHEMIA 60 (2), 101-108'
# ('Prognostic Factors in Liver Failure in Children by Discriminant Analysis of Clinical Data. A Chemometric Approach', 'HF Pop, C Sarbu, A Stefanescu, A Bizo, TL Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI CHEMIA 60 (2), 101-108', '2015')
# INSERT INTO publications_cache SET Title='Constraint optimization-based component selection problem', ProfessorId='5', PublicationDate='2008-01-01', Authors='A Vescan, HF Pop', Affiliations='Studia Univ, Babes-Bolyai, Informatica 53 (2)'
# ('Constraint optimization-based component selection problem', 'A Vescan, HF Pop', 'Studia Univ, Babes-Bolyai, Informatica 53 (2)', '2008')
# INSERT INTO publications_cache SET Title='Education for engineering students-The case of logic', ProfessorId='5', PublicationDate='2007-01-01', Authors='H Pop, L Pop', Affiliations='Proceedings 6th International Conference on Electromechanical and Power …'
# ('Education for engineering students-The case of logic', 'H Pop, L Pop', 'Proceedings 6th International Conference on Electromechanical and Power …', '2007')
# INSERT INTO publications_cache SET Title='Tracking mistakes in software measurement using fuzzy data analysis', ProfessorId='5', PublicationDate='2005-01-01', Authors='HF Pop, M Frenţiu', Affiliations='The 4-th International Conference RoEduNet Romania (Sovata, Târgu-Mures, 150-157'
# ('Tracking mistakes in software measurement using fuzzy data analysis', 'HF Pop, M Frenţiu', 'The 4-th International Conference RoEduNet Romania (Sovata, Târgu-Mures, 150-157', '2005')
# INSERT INTO publications_cache SET Title='Sisteme inteligente în probleme de clasificare', ProfessorId='5', PublicationDate='2004-01-01', Authors='HF Pop', Affiliations='Mediamira'
# ('Sisteme inteligente în probleme de clasificare', 'HF Pop', 'Mediamira', '2004')
# INSERT INTO publications_cache SET Title='Programare în inteligenţa artificială: LISP si PROLOG', ProfessorId='5', PublicationDate='2003-01-01', Authors='HF Pop, G Şerban', Affiliations='Editura Albastră'
# ('Programare în inteligenţa artificială: LISP si PROLOG', 'HF Pop, G Şerban', 'Editura Albastră', '2003')
# INSERT INTO publications_cache SET Title='Rational Classification of the Chemical Elements', ProfessorId='5', PublicationDate='2000-01-01', Authors='O Horovitz, C Sârbu, HF Pop', Affiliations='Dacia Publisher House, Cluj-Napoca'
# ('Rational Classification of the Chemical Elements', 'O Horovitz, C Sârbu, HF Pop', 'Dacia Publisher House, Cluj-Napoca', '2000')
# INSERT INTO publications_cache SET Title='Classification procedure for selectivity control in acrylonitrile electroreduction', ProfessorId='5', PublicationDate='1993-01-01', Authors='DA Lowy, D Dumitrescu, L Oniciu, HF Pop, S Kiss-Szetsi', Affiliations='The 7th International Forum Process Analytical Chemistry (Process Analysis …'
# ('Classification procedure for selectivity control in acrylonitrile electroreduction', 'DA Lowy, D Dumitrescu, L Oniciu, HF Pop, S Kiss-Szetsi', 'The 7th International Forum Process Analytical Chemistry (Process Analysis …', '1993')
# INSERT INTO publications_cache SET Title='Improving movement analysis in physical therapy systems based on kinect interaction', ProfessorId='5', PublicationDate='2017-01-01', Authors='AD Călin, H F. Pop, R F. Boian', Affiliations='Proceedings of the 31st International BCS Human Computer Interaction …'
# ('Improving movement analysis in physical therapy systems based on kinect interaction', 'AD Călin, H F. Pop, R F. Boian', 'Proceedings of the 31st International BCS Human Computer Interaction …', '2017')
# INSERT INTO publications_cache SET Title='A fuzzy incremental clustering approach to hybrid data discovery', ProfessorId='5', PublicationDate='2012-01-01', Authors='RD Gaceanu, HF Pop', Affiliations='Acta electrotechnica et informatica 12 (2), 16'
# ('A fuzzy incremental clustering approach to hybrid data discovery', 'RD Gaceanu, HF Pop', 'Acta electrotechnica et informatica 12 (2), 16', '2012')
# INSERT INTO publications_cache SET Title='An incremental approach to the set covering problem', ProfessorId='5', PublicationDate='2012-01-01', Authors='RD Gaceanu, HF Pop', Affiliations='Studia Universitatis Babes-Bolyai Series Informatica 47 (2), 61-72'
# ('An incremental approach to the set covering problem', 'RD Gaceanu, HF Pop', 'Studia Universitatis Babes-Bolyai Series Informatica 47 (2), 61-72', '2012')
# INSERT INTO publications_cache SET Title='AP041 Joining the EuReCA–The Romanian Registry on Cardiac arrest–a year later', ProfessorId='5', PublicationDate='2011-01-01', Authors='H Sabau, O Tudorache, H Pop, V Georgescu, V Strambu, I Dimitriu, ...', Affiliations='Resuscitation 82, S19'
# ('AP041 Joining the EuReCA–The Romanian Registry on Cardiac arrest–a year later', 'H Sabau, O Tudorache, H Pop, V Georgescu, V Strambu, I Dimitriu, ...', 'Resuscitation 82, S19', '2011')
# INSERT INTO publications_cache SET Title='A fuzzy clustering algorithm for dynamic environments', ProfessorId='5', PublicationDate='2011-01-01', Authors='RD Gaceanu, HF POP', Affiliations='KEPT2011: Knowledge Engineering Principles and Techniques, Selected Papers …'
# ('A fuzzy clustering algorithm for dynamic environments', 'RD Gaceanu, HF POP', 'KEPT2011: Knowledge Engineering Principles and Techniques, Selected Papers …', '2011')
# INSERT INTO publications_cache SET Title='Romanian registry on cardiac arrest—A piece in the puzzle-Romanian contribution in the EuReCA project', ProfessorId='5', PublicationDate='2010-01-01', Authors='V Georgescu, H Pop, O Tudorache, H Sabau, C Ciontu, I Dimitriu, ...', Affiliations='Resuscitation 81 (2), S39'
# ('Romanian registry on cardiac arrest—A piece in the puzzle-Romanian contribution in the EuReCA project', 'V Georgescu, H Pop, O Tudorache, H Sabau, C Ciontu, I Dimitriu, ...', 'Resuscitation 81 (2), S39', '2010')
# INSERT INTO publications_cache SET Title='Effort Estimation by Analogy based on Soft Computing Methods, KEPT2009: Knowledge Engineering: Principles and Techniques, Selected Papers', ProfessorId='5', PublicationDate='2009-01-01', Authors='HF Pop, M Frenţiu', Affiliations='Cluj University Press, Cluj-Napoca'
# ('Effort Estimation by Analogy based on Soft Computing Methods, KEPT2009: Knowledge Engineering: Principles and Techniques, Selected Papers', 'HF Pop, M Frenţiu', 'Cluj University Press, Cluj-Napoca', '2009')
# INSERT INTO publications_cache SET Title='A New Component Selection Algorithm Based on Metrics and Fuzzy Clustering', ProfessorId='5', PublicationDate='2009-01-01', Authors='C Serban, A Vescan, HF Pop', Affiliations='Creative Mathematics and Informatics 1 (3), 505-510'
# ('A New Component Selection Algorithm Based on Metrics and Fuzzy Clustering', 'C Serban, A Vescan, HF Pop', 'Creative Mathematics and Informatics 1 (3), 505-510', '2009')
# INSERT INTO publications_cache SET Title='Fundamentals of Programming', ProfessorId='5', PublicationDate='2006-01-01', Authors='M Frenţiu, HF Pop', Affiliations='Cluj University Press'
# ('Fundamentals of Programming', 'M Frenţiu, HF Pop', 'Cluj University Press', '2006')
# INSERT INTO publications_cache SET Title='Improving Virtual Team Performance: An Empirical Approach', ProfessorId='5', PublicationDate='2006-01-01', Authors='D Radoiu, C Enachescu, HF Pop', Affiliations='A research paper of Sysgenic Sourcing, Available at sourcing. sysgenic. com …'
# ('Improving Virtual Team Performance: An Empirical Approach', 'D Radoiu, C Enachescu, HF Pop', 'A research paper of Sysgenic Sourcing, Available at sourcing. sysgenic. com …', '2006')
# INSERT INTO publications_cache SET Title='Supervised fuzzy classifiers', ProfessorId='5', PublicationDate='1995-01-01', Authors='HF Pop', Affiliations='Studia Universitatis Babes-Bolyai, Series Mathematica 40 (3), 89-100'
# ('Supervised fuzzy classifiers', 'HF Pop', 'Studia Universitatis Babes-Bolyai, Series Mathematica 40 (3), 89-100', '1995')
# INSERT INTO publications_cache SET Title='OPTIMUM SELECTIONS AND COMBINATION OF SOLVENT SYSTEMS IN THIN-LAYER CHROMATOGRAPHY, USING THE FUZZY SET-THEORY', ProfessorId='5', PublicationDate='1993-01-01', Authors='C Sârbu, D Dumitrescu, H Pop', Affiliations='Revista de Chimie 44 (5), 450-459'
# ('OPTIMUM SELECTIONS AND COMBINATION OF SOLVENT SYSTEMS IN THIN-LAYER CHROMATOGRAPHY, USING THE FUZZY SET-THEORY', 'C Sârbu, D Dumitrescu, H Pop', 'Revista de Chimie 44 (5), 450-459', '1993')
# INSERT INTO publications_cache SET Title='Preliminary measurements in identifying design flaws', ProfessorId='5', PublicationDate='2017-01-01', Authors='C SERBAN, A VESCAN, HF POP', Affiliations='Studia Universitatis Babes-Bolyai, Series Informatica 62 (1), 60-74'
# ('Preliminary measurements in identifying design flaws', 'C SERBAN, A VESCAN, HF POP', 'Studia Universitatis Babes-Bolyai, Series Informatica 62 (1), 60-74', '2017')
# INSERT INTO publications_cache SET Title='AN AGENT BASED APPROACH FOR PARALLEL CONSTRAINT VERIFICATION', ProfessorId='5', PublicationDate='2013-01-01', Authors='RD Gaceanu, HF Pop, SA Sotoc', Affiliations='Studia Universitatis Babes-Bolyai, Series Informatica 58 (3), 5-16'
# ('AN AGENT BASED APPROACH FOR PARALLEL CONSTRAINT VERIFICATION', 'RD Gaceanu, HF Pop, SA Sotoc', 'Studia Universitatis Babes-Bolyai, Series Informatica 58 (3), 5-16', '2013')
# INSERT INTO publications_cache SET Title='An agent based approach for parallel constraint verification', ProfessorId='5', PublicationDate='2013-01-01', Authors='RD Gaceanu, HF Pop, SA SOTOC', Affiliations='Studia Universitatis Babes-Bolyai Series Informatica 58 (3), 5-16'
# ('An agent based approach for parallel constraint verification', 'RD Gaceanu, HF Pop, SA SOTOC', 'Studia Universitatis Babes-Bolyai Series Informatica 58 (3), 5-16', '2013')
# INSERT INTO publications_cache SET Title='Stereomatching using radiometric invariant measures', ProfessorId='5', PublicationDate='2011-01-01', Authors='A Miron, S Ainouz, A Rogozan, A Bensrhair, HF POP', Affiliations='UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 91'
# ('Stereomatching using radiometric invariant measures', 'A Miron, S Ainouz, A Rogozan, A Bensrhair, HF POP', 'UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 91', '2011')
# INSERT INTO publications_cache SET Title='Improving similarity join algorithms using fuzzy clustering technique', ProfessorId='5', PublicationDate='2009-01-01', Authors='L Tan, F Fotouhi, W Grosky, HF Pop, N Mouaddib', Affiliations='2009 IEEE International Conference on Data Mining Workshops, 545-550'
# ('Improving similarity join algorithms using fuzzy clustering technique', 'L Tan, F Fotouhi, W Grosky, HF Pop, N Mouaddib', '2009 IEEE International Conference on Data Mining Workshops, 545-550', '2009')
# INSERT INTO publications_cache SET Title='OVERVIEW OF FUZZY METHODS FOR EFFORT ESTIMATION BY ANALOGY.', ProfessorId='5', PublicationDate='2009-01-01', Authors='M Frenţiu, HF Pop', Affiliations='Studia Universitatis Babes-Bolyai, Informatica'
# ('OVERVIEW OF FUZZY METHODS FOR EFFORT ESTIMATION BY ANALOGY.', 'M Frenţiu, HF Pop', 'Studia Universitatis Babes-Bolyai, Informatica', '2009')
# INSERT INTO publications_cache SET Title='Lighting quality-component of indoor environment', ProfessorId='5', PublicationDate='2009-01-01', Authors='F Pop, HF Pop, M Pop', Affiliations='LUX Eur, 499-506'
# ('Lighting quality-component of indoor environment', 'F Pop, HF Pop, M Pop', 'LUX Eur, 499-506', '2009')
# INSERT INTO publications_cache SET Title='Applications of principal components methods', ProfessorId='5', PublicationDate='2008-01-01', Authors='HF Pop, M Frentiu', Affiliations='2008 First International Conference on Complexity and Intelligence of the …'
# ('Applications of principal components methods', 'HF Pop, M Frentiu', '2008 First International Conference on Complexity and Intelligence of the …', '2008')
# INSERT INTO publications_cache SET Title='Programming Fundamentals', ProfessorId='5', PublicationDate='2006-01-01', Authors='M Frenţiu, HF Pop, G Şerban', Affiliations='Presa Universitară Clujeană'
# ('Programming Fundamentals', 'M Frenţiu, HF Pop, G Şerban', 'Presa Universitară Clujeană', '2006')
# INSERT INTO publications_cache SET Title='Distance Learning and Supporting Tools at Babeş-Bolyai University', ProfessorId='5', Authors='FM Boian, RF Boian, A Vancea, HF Pop', Affiliations='1'
# ('Distance Learning and Supporting Tools at Babeş-Bolyai University', 'FM Boian, RF Boian, A Vancea, HF Pop', '1', '')
# INSERT INTO publications_cache SET Title='CHARACTERIZATION AND CLASSIFICATION OF MEDICINAL PLANT EXTRACTS ACCORDING TO THEIR ANTIOXIDANT ACTIVITY USING HIGH-PERFORMANCE LIQUID CHROMATOGRAPHY AND MULTIVARIATE ANALYSIS.', ProfessorId='5', PublicationDate='2020-01-01', Authors='IM Simion, AC MOȚ, RD GĂCEANU, HF Pop, C Sarbu', Affiliations='Studia Universitatis Babes-Bolyai, Chemia 65 (1)'
# ('CHARACTERIZATION AND CLASSIFICATION OF MEDICINAL PLANT EXTRACTS ACCORDING TO THEIR ANTIOXIDANT ACTIVITY USING HIGH-PERFORMANCE LIQUID CHROMATOGRAPHY AND MULTIVARIATE ANALYSIS.', 'IM Simion, AC MOȚ, RD GĂCEANU, HF Pop, C Sarbu', 'Studia Universitatis Babes-Bolyai, Chemia 65 (1)', '2020')
# INSERT INTO publications_cache SET Title='A Comparison Study of Similarity Measures in Rough Sets Clustering', ProfessorId='5', PublicationDate='2019-01-01', Authors='A Szederjesi-Dragomir, RD Găceanu, HF Pop, C Sârbu', Affiliations='2019 IEEE 15th International Scientific Conference on Informatics, 000037-000042'
# ('A Comparison Study of Similarity Measures in Rough Sets Clustering', 'A Szederjesi-Dragomir, RD Găceanu, HF Pop, C Sârbu', '2019 IEEE 15th International Scientific Conference on Informatics, 000037-000042', '2019')
# INSERT INTO publications_cache SET Title='A Machine Learning Perspective for Order Reduction in Electrical Motors Modeling', ProfessorId='5', PublicationDate='2019-01-01', Authors='M Nutu, HF Pop, C Martis, SI Cosman, AM Nicorici', Affiliations='2019 21st International Symposium on Symbolic and Numeric Algorithms for …'
# ('A Machine Learning Perspective for Order Reduction in Electrical Motors Modeling', 'M Nutu, HF Pop, C Martis, SI Cosman, AM Nicorici', '2019 21st International Symposium on Symbolic and Numeric Algorithms for …', '2019')
# INSERT INTO publications_cache SET Title='Principal Component Analysis for Computation of the Magnetization Characteristics of Synchronous Reluctance Machine', ProfessorId='5', PublicationDate='2018-01-01', Authors='M Nutu, R Martis, HF Pop, C Martis', Affiliations='2018 AEIT International Annual Conference, 1-6'
# ('Principal Component Analysis for Computation of the Magnetization Characteristics of Synchronous Reluctance Machine', 'M Nutu, R Martis, HF Pop, C Martis', '2018 AEIT International Annual Conference, 1-6', '2018')
# INSERT INTO publications_cache SET Title='SPECTROPHOTOMETRIC CHARACTERIZATION OF ROUMANIAN MEDICINAL HERBS ASSISTED BY ROBUST CHEMOMETRICS EXPERTISE', ProfessorId='5', PublicationDate='2018-01-01', Authors='IM Simion, HF POPb, C Sarbu', Affiliations='Rev. Roum. Chim 63 (5-6), 489-496'
# ('SPECTROPHOTOMETRIC CHARACTERIZATION OF ROUMANIAN MEDICINAL HERBS ASSISTED BY ROBUST CHEMOMETRICS EXPERTISE', 'IM Simion, HF POPb, C Sarbu', 'Rev. Roum. Chim 63 (5-6), 489-496', '2018')
# INSERT INTO publications_cache SET Title='The Best Writing on Mathematics 2015', ProfessorId='5', PublicationDate='2016-01-01', Authors='HF Pop', Affiliations='STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 61 (1), 123-124'
# ('The Best Writing on Mathematics 2015', 'HF Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 61 (1), 123-124', '2016')
# INSERT INTO publications_cache SET Title='PROGNOSTIC FACTORS IN LIVER FAILURE IN CHILDREN BY DISCRIMINANT ANALYSIS OF CLINICAL DATA. A CHEMOMETRIC APPROACH.', ProfessorId='5', PublicationDate='2015-01-01', Authors='C SÂRBU, A BIZO, TL POP, HF POP, ANA ŞTEFANESCU', Affiliations='Studia Universitatis Babes-Bolyai, Chemia 60'
# ('PROGNOSTIC FACTORS IN LIVER FAILURE IN CHILDREN BY DISCRIMINANT ANALYSIS OF CLINICAL DATA. A CHEMOMETRIC APPROACH.', 'C SÂRBU, A BIZO, TL POP, HF POP, ANA ŞTEFANESCU', 'Studia Universitatis Babes-Bolyai, Chemia 60', '2015')
# INSERT INTO publications_cache SET Title='The Best Writing on Mathematics 2014', ProfessorId='5', PublicationDate='2014-01-01', Authors='HF Pop', Affiliations='STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 59 (3), 393-394'
# ('The Best Writing on Mathematics 2014', 'HF Pop', 'STUDIA UNIVERSITATIS BABES-BOLYAI MATHEMATICA 59 (3), 393-394', '2014')
# INSERT INTO publications_cache SET Title='Medical procedure breaches detection using a fuzzy clustering approach', ProfessorId='5', PublicationDate='2014-01-01', Authors='R Găceanu, H Pop', Affiliations='Open Computer Science 4 (3), 127-140'
# ('Medical procedure breaches detection using a fuzzy clustering approach', 'R Găceanu, H Pop', 'Open Computer Science 4 (3), 127-140', '2014')
# INSERT INTO publications_cache SET Title='An incremental clustering approach to the set covering problem', ProfessorId='5', PublicationDate='2012-01-01', Authors='RD Gaceanu, HF Pop', Affiliations='Zoltán Csörnyei (Ed.), 45'
# ('An incremental clustering approach to the set covering problem', 'RD Gaceanu, HF Pop', 'Zoltán Csörnyei (Ed.), 45', '2012')
# INSERT INTO publications_cache SET Title='Automatic criteria-based configuration for the component selection problem', ProfessorId='5', PublicationDate='2012-01-01', Authors='A Vescan, HF Pop', Affiliations='International Journal of Computer Information Systems and Industrial …'
# ('Automatic criteria-based configuration for the component selection problem', 'A Vescan, HF Pop', 'International Journal of Computer Information Systems and Industrial …', '2012')
# INSERT INTO publications_cache SET Title='Recent developments in fuzzy statistical analysis', ProfessorId='5', PublicationDate='2010-01-01', Authors='HF Pop', Affiliations='MaCS’10, 47'
# ('Recent developments in fuzzy statistical analysis', 'HF Pop', 'MaCS’10, 47', '2010')
# INSERT INTO publications_cache SET Title='PROCESSING ECG DATA USING MULTIVARIATE DATA ANALYSIS', ProfessorId='5', PublicationDate='2010-01-01', Authors='MV PUŞCĂ, HF POP, NM ROMAN, V IANCU', Affiliations='ACADEMY OF ROMANIAN SCIENTISTS, 23'
# ('PROCESSING ECG DATA USING MULTIVARIATE DATA ANALYSIS', 'MV PUŞCĂ, HF POP, NM ROMAN, V IANCU', 'ACADEMY OF ROMANIAN SCIENTISTS, 23', '2010')
# INSERT INTO publications_cache SET Title='M. Effort estimation by analogy based on soft computing methods', ProfessorId='5', PublicationDate='2009-01-01', Authors='HF POP, M FRENTIU', Affiliations='KEPT 2009 International Conference Knowledge Engineering Principles and …'
# ('M. Effort estimation by analogy based on soft computing methods', 'HF POP, M FRENTIU', 'KEPT 2009 International Conference Knowledge Engineering Principles and …', '2009')
# INSERT INTO publications_cache SET Title='Knowledge Engineering: Principles and Techniques: KEPT 2009: Cluj-Napoca, July 2-4, 2009', ProfessorId='5', PublicationDate='2009-01-01', Authors='M Frențiu, HF Pop', Affiliations='Cluj University Press'
# ('Knowledge Engineering: Principles and Techniques: KEPT 2009: Cluj-Napoca, July 2-4, 2009', 'M Frențiu, HF Pop', 'Cluj University Press', '2009')
# INSERT INTO publications_cache SET Title='Iluminat eficient energetic în locuinţe', ProfessorId='5', PublicationDate='2008-01-01', Authors='F Pop, D Beu, HF Pop, C Ciugudeanu', Affiliations='Revista Română de Informatică şi Automatică 18 (3), 101-112'
# ('Iluminat eficient energetic în locuinţe', 'F Pop, D Beu, HF Pop, C Ciugudeanu', 'Revista Română de Informatică şi Automatică 18 (3), 101-112', '2008')
# INSERT INTO publications_cache SET Title='A Tutorial on Object-Oriented Functional Programming', ProfessorId='5', PublicationDate='2007-01-01', Authors='HF Pop', Affiliations='Central European Functional Programming School, 228-249'
# ('A Tutorial on Object-Oriented Functional Programming', 'HF Pop', 'Central European Functional Programming School, 228-249', '2007')
# INSERT INTO publications_cache SET Title='ON SOFTWARE ATTRIBUTES RELATIONSHIP USING A NEW FUZZY C-BIPARTITIONING METHOD', ProfessorId='5', PublicationDate='2007-01-01', Authors='HF Pop, M Frentiu', Affiliations='Studia Universitatis Babes-Bolyai, Informatica Special Issue, 219-226'
# ('ON SOFTWARE ATTRIBUTES RELATIONSHIP USING A NEW FUZZY C-BIPARTITIONING METHOD', 'HF Pop, M Frentiu', 'Studia Universitatis Babes-Bolyai, Informatica Special Issue, 219-226', '2007')
# INSERT INTO publications_cache SET Title='Management of web pages using XML documents', ProfessorId='5', PublicationDate='2007-01-01', Authors='L T ÂMBULEA, HF POP', Affiliations='Studia Universitatis Babes-Bolyai, Informatica Special Issue, 236-243'
# ('Management of web pages using XML documents', 'L T ÂMBULEA, HF POP', 'Studia Universitatis Babes-Bolyai, Informatica Special Issue, 236-243', '2007')
# INSERT INTO publications_cache SET Title='Desired employment/Occupational field', ProfessorId='5', PublicationDate='2003-01-01', Authors='N Italian, G Male', Affiliations='Cell 39, 081678652'
# ('Desired employment/Occupational field', 'N Italian, G Male', 'Cell 39, 081678652', '2003')
# INSERT INTO publications_cache SET Title='Appraisal of indoor lighting systems quality', ProfessorId='5', PublicationDate='2001-01-01', Authors='M POP, HF POP, F POP', Affiliations='Ingineria Iluminatului, 37'
# ('Appraisal of indoor lighting systems quality', 'M POP, HF POP, F POP', 'Ingineria Iluminatului, 37', '2001')
# INSERT INTO publications_cache SET Title='Papers from the 1999 Symposium on Mathematical Chemistry, Duluth, MN, May 1999-MOLECULAR MODELING-Structural Analysis of Transition Metal bX Substituent Interactions. Toward …', ProfessorId='5', PublicationDate='2000-01-01', Authors='TR Cundari, J Deng, HF Pop, C Sarbu', Affiliations='Journal of Chemical Information and Computer Sciences 40 (4), 1052-1061'
# ('Papers from the 1999 Symposium on Mathematical Chemistry, Duluth, MN, May 1999-MOLECULAR MODELING-Structural Analysis of Transition Metal bX Substituent Interactions. Toward …', 'TR Cundari, J Deng, HF Pop, C Sarbu', 'Journal of Chemical Information and Computer Sciences 40 (4), 1052-1061', '2000')
# INSERT INTO publications_cache SET Title='Recognition of the forms applied to chemical elements', ProfessorId='5', PublicationDate='2000-01-01', Authors='O Horowitz, C Sarbu, HF Pop', Affiliations='REVISTA DE CHIMIE 51 (1), 17-29'
# ('Recognition of the forms applied to chemical elements', 'O Horowitz, C Sarbu, HF Pop', 'REVISTA DE CHIMIE 51 (1), 17-29', '2000')
# INSERT INTO publications_cache SET Title='REGRESIE FUZZY. II. CAZUL PUNCTELOR EXTREME (OUTLIERS)', ProfessorId='5', PublicationDate='1997-01-01', Authors='HF POP, C SARBU', Affiliations='Revista de chimie 48 (10-11), 888-891'
# ('REGRESIE FUZZY. II. CAZUL PUNCTELOR EXTREME (OUTLIERS)', 'HF POP, C SARBU', 'Revista de chimie 48 (10-11), 888-891', '1997')
# INSERT INTO publications_cache SET Title='REGRESIE FUZZY. I. CAZUL HETEROSCEDASTIC', ProfessorId='5', PublicationDate='1997-01-01', Authors='C SARBU, H POP', Affiliations='Revista de chimie 48 (8), 732-737'
# ('REGRESIE FUZZY. I. CAZUL HETEROSCEDASTIC', 'C SARBU, H POP', 'Revista de chimie 48 (8), 732-737', '1997')
# INSERT INTO publications_cache SET Title='Desired employment Occupational field', ProfessorId='5', PublicationDate='1992-01-01', Authors='F Horia', Affiliations='Education and training 1995'
# ('Desired employment Occupational field', 'F Horia', 'Education and training 1995', '1992')
# INSERT INTO publications_cache SET Title='KEPT2013: THE FOURTH INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING, PRINCIPLES AND TECHNIQUES', ProfessorId='5', Authors='M FRENTIU, HF POP, S MOTOGNA', Affiliations='UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 5'
# ('KEPT2013: THE FOURTH INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING, PRINCIPLES AND TECHNIQUES', 'M FRENTIU, HF POP, S MOTOGNA', 'UNIVERSITATIS BABEŞ-BOLYAI INFORMATICA, 5', '')
# INSERT INTO publications_cache SET Title='Object-oriented logic programming', ProfessorId='5', Authors='HF Pop, MM Dogaru', Affiliations='LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat'
# ('Object-oriented logic programming', 'HF Pop, MM Dogaru', 'LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat', 'LSD–Lighting Systems Desing–un program pentru proiectarea sistemelor de iluminat')
# INSERT INTO publications_cache SET Title='F Horia, POP Florin', ProfessorId='5', Authors='SAADI: Software for Fuzzy Clustering and Related Fields', Affiliations='F Horia'
# ('F Horia, POP Florin', 'SAADI: Software for Fuzzy Clustering and Related Fields', 'F Horia', 'F Horia')
# INSERT INTO publications_cache SET Title='Residential Energy Efficient Lighting', ProfessorId='5', Authors='POP Florin, F Horia', Affiliations='A guide for writing a scientific paper'
# ('Residential Energy Efficient Lighting', 'POP Florin, F Horia', 'A guide for writing a scientific paper', 'A guide for writing a scientific paper')
# INSERT INTO publications_cache SET Title='M Frenţiu, HF Pop', ProfessorId='5', Authors='Metode de recunoastere a formelor bazate pe agenti', Affiliations='UBB Îndrumator, HF Pop'
# ('M Frenţiu, HF Pop', 'Metode de recunoastere a formelor bazate pe agenti', 'UBB Îndrumator, HF Pop', 'UBB Îndrumator, HF Pop')
# INSERT INTO publications_cache SET Title='THE FIRST INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING PRINCIPLES AND TECHNIQUES (KEPT 2007)', ProfessorId='5', Authors='D TATAR, HF Pop, M FRENTIU, D Dumitrescu', Affiliations='COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER'
# ('THE FIRST INTERNATIONAL CONFERENCE ON KNOWLEDGE ENGINEERING PRINCIPLES AND TECHNIQUES (KEPT 2007)', 'D TATAR, HF Pop, M FRENTIU, D Dumitrescu', 'COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER', 'COMMON MISTAKES IN WRITING A SCIENTIFIC PAPER')

# %%
mariadb_connection.close()

# %% [markdown]
# # Conclusion
# ### In the end, the DB only required ~1 manual modifications with this code.
# This was first stored in a DB cache table which is a duplicate of the main, reviewed, then inserted in the main table.

# %% [markdown]
# ![Screenshot](Images/Finished.PNG)
